# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"}

url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

r = requests.get(url, headers = headers)
r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(r.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"gdpr":{"consentLanguage":"en"},"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script async="" src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport"/>
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://www.transfermarkt.com/marktwertetop/wertvollstespieler" property="og:url"/>
# <link href="https://www.transfermarkt.de/marktwertetop/wertvollstespieler" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/marktwertetop/wertvollstespieler" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/marktwertetop/wertvollstespieler" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.transfermarkt.ch/marktwertetop/wertvollstespieler" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/marktwertetop/wertvollstespieler" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/marktwertetop/wertvollstespieler" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/marktwertetop/wertvollstespieler" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/marktwertetop/wertvollstespieler" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/marktwertetop/wertvollstespieler" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/marktwertetop/wertvollstespieler" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/marktwertetop/wertvollstespieler" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/marktwertetop/wertvollstespieler" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/marktwertetop/wertvollstespieler" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.world/marktwertetop/wertvollstespieler" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.world/marktwertetop/wertvollstespieler" hreflang="world" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/marktwertetop/wertvollstespieler" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/marktwertetop/wertvollstespieler" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/marktwertetop/wertvollstespieler" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/marktwertetop/wertvollstespieler" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/marktwertetop/wertvollstespieler" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/marktwertetop/wertvollstespieler" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/marktwertetop/wertvollstespieler" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/marktwertetop/wertvollstespieler" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/marktwertetop/wertvollstespieler" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.ro/marktwertetop/wertvollstespieler" hreflang="ro" rel="alternate"/>
# <link href="https://www.transfermarkt.gr/marktwertetop/wertvollstespieler" hreflang="el-GR" rel="alternate"/>
# <link href="https://www.transfermarkt.co.kr/marktwertetop/wertvollstespieler" hreflang="ko-KR" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/marktwertetop/wertvollstespieler" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/marktwertetop/wertvollstespieler" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/marktwertetop/wertvollstespieler" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.pe/marktwertetop/wertvollstespieler" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.my/marktwertetop/wertvollstespieler" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/marktwertetop/wertvollstespieler" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/marktwertetop/wertvollstespieler" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/marktwertetop/wertvollstespieler?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.min.css?lm=1700238195" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1700238214" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1700238204" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1700238204" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1700238204" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1700238203" type="text/javascript"></script>
# <title>Most valuable players | Transfermarkt</title>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <tm-consent embed="..." no-checkbox="" type="infonline"></tm-consent>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': 'wertvollstespieler',
#                 'content_group4': '',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         window.tmGaId = "UA-3816204-13";
#     </script>
# <!--Tisoomi-->
# <script type="text/javascript">
# /* 19124713 */ !function(e,t){function n(e,t){var n=ve(e);if(!n)return n;if(""!=t)for(var i=0;i<t.length;i++){var a=l(t,i);"^"==a&&(n=n.parentNode),"<"==a&&(n=n.previousElementSibling),">"==a&&(n=n.nextElementSibling),"y"==a&&(n=n.firstChild)}return n}function i(e,t){var n=pe(t);return{x:e.clientX-n.left,y:e.clientY-n.top}}function a(e){for(var t=0,n=0;e;)t+=e.offsetLeft+e.clientLeft,n+=e.offsetTop+e.clientTop,e=e.offsetParent;return{x:t,y:n}}function r(e,t){var n=0,i=0,r=a(t);return(e.pageX||e.pageY)&&(n=e.pageX,i=e.pageY),(e.clientX||e.clientY)&&(n=e.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,i=e.clientY+document.body.scrollTop+document.documentElement.scrollTop),n-=r.x,i-=r.y,{x:n,y:i}}function d(e,t){return le(t)?i(e,t):r(e,t)}function o(e,t){e.addEventListener?v(e,"click",t,!0):e.attachEvent&&e.attachEvent("onclick",function(){return t.call(e,window.event)})}function h(t,n){return e[y("c2V0VGltZW91dA==")](t,n)}function f(e){return parseInt(e.toString().split(".")[0],10)}function l(e,t){return e[t]}function p(){return Ae=(Be*Ae+De)%Je}function u(){return p()/(Je-1)}function s(){return u()}function c(e,t){return e>t?e:t}function R(){for(var e="",t=65;t<91;t++)e+=j(t);for(var t=97;t<123;t++)e+=j(t);return e}function j(e){return l(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+l("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}~",e-32)}function y(e){var t,n,i,a,r,d,o,h=R()+"0123456789+/=",f="",p=0;for(e=e.replace(/[^A-Za-z0-9\+\/\=]/g,"");p<e.length;)a=h.indexOf(l(e,p++)),r=h.indexOf(l(e,p++)),d=h.indexOf(l(e,p++)),o=h.indexOf(l(e,p++)),t=a<<2|r>>4,n=(15&r)<<4|d>>2,i=(3&d)<<6|o,f+=j(t),64!=d&&(f+=j(n)),64!=o&&(f+=j(i));return f}function U(e){for(var t=R()+"0123456789+/=",n=e.length-1,i=-1,a="";i<n;){var r=e.charCodeAt(++i)<<16|e.charCodeAt(++i)<<8|e.charCodeAt(++i);a+=t[r>>>18&63]+t[r>>>12&63]+t[r>>>6&63]+t[63&r]}var d=e.length%3;if(d>0)for(a=a.slice(0,d-3);a.length%4!=0;)a+="=";return a}function x(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(e){return"unknown"}}function v(t,n,i,a){a=a||!1;try{t.addEventListener(n,i,a),e.yejahClne.push([t,n,i,a])}catch(r){t.attachEvent&&(t.attachEvent("on"+n,i),e.yejahClne.push([t,n,i,a]))}}function z(e){if(!e)return"";for(var t=y("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),n="",i=0;i<e.length;i++){n+=t.indexOf(e[i])>-1?y("XA==")+e[i]:e[i]}return n}function V(e){if(!e)return"";var t="";return e.id&&e.id.length>0&&(t+="#"+z(e.id)),e.className&&e.className.length>0&&(t+="."+z(e.className).split(" ").filter(function(e){return e&&e.length>0}).join(".")),t}function m(e){_e[e]=!1}function g(t,n){var i=Ce++;e.yejahClni&&e.yejahClni.push(i),_e[i]=!0;var a=function(e){return function(){t.call(null),_e[i]&&h(a,e)}}(n);return h(a,n),i}function w(e){var t=!1;return Object.keys(e).forEach(function(n){t=t||e[n]}),!t}function E(e,t){return e&&(e.consents&&e.consents[t]||e.legitimateInterests&&e.legitimateInterests[t])}function T(t){return!!e.yejah2f6Flags.strictNCNA&&(E(t,2)&&E(t,7)&&E(t,9)&&E(t,10))}function F(t){return e[y("ZW5jb2RlVVJJQ29tcG9uZW50")](t)}function b(e,t,n){var i=function(){return!!t()&&(n(),!0)};if(!i()){var a=g(function(){i()&&m(a)},250);i()}}function H(e){W(e)}function W(e){if(e.yejah7ecsdl&&!e.yejah2a8Injct){e.yejah2a8Injct=!0,e.yejah9a5Pc={},e.yejah7f5Oc=[],e.yejahce0Am={},e.yejah016Av={},e.yejaha4fAw={},e.yejah367Rqr={},e.yejahc44Rqq=[],e.yejah016Avt={},e.yejahb30Ev={};var n=[];if(!e.yejah2f6Flags.welect.eenabled||EJJKJWelect()){if(yejah2f6Flags.ptbeals){var i=yejah2f6Flags.bae86it,a=yejah2f6Flags.mb217el||10,r=yejah2f6Flags.ig173BP,d=function(){var e=ie("style");e.type="text/css";var n=!1,i=ie("style");i.type="text/css";var a=!1;return function(d,o){if(o)if("b"!==d||n){if("r"===d)if(a){var h=i,f=h.sheet;f.insertRule(o,0)}else a=!0,ae(i,o),re(t.body,i)}else{if(n=!0,r)for(var l=0;l<r.length;l++)o=o.replace(new RegExp("([;{])"+r[l]+": [^;]+;","g"),"$1");var h="[^:;{",f="!important;";o=o.replace(new RegExp(h+"}]+: [^;]+\\s"+ ...
# ;ae(r,""+y(Me(y("..."),-3))),we(r.childNodes,function(t,i){ce(n,i),e.yejahCln.push(i)}),e.yejahCln.push(n)}function c(t){var n=ie("div");a[""+y(Me(y("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94WzRRdmU2VX0="),-3))]=n,a[""+y(Me(y("UkdufVJEQEA="),-3))]=n,i[""+y(Me(y("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94WzRRdmU2VX0="),-3))]=n,ce(t,n),e.yejahd1484.w[8938]=n;var r=ie("div");ae(r,""+y(Me(y("..."),-3))),we(r.childNodes,function(t,i){ce(n,i),e.yejahCln.push(i)}),X([{function:function(e,t){e.remove&&e.remove()}}],n,8938),e.yejahCln.push(n)}function R(t){var n=ie("div");a[""+y(Me(y("WTVJdmVLRWtmSll8WzRnVlRZRVRVWUxA"),-3))]=n,a[""+y(Me(y("UkdcOFF6QEA="),-3))]=n,i[""+y(Me(y("WTVJdmVLRWtmSll8WzRnVlRZRVRVWUxA"),-3))]=n,xe(n,"cUXuEeQqq"),ce(t,n),e.yejahd1484.w[8697]=n,e.yejahCln.push(n)}function j(t){if(e.yejahf89Mobile&&(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1)){var n=a[""+y(Me(y("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbfUhA"),-3))];n&&t(n)}}function U(t){var n=ie("div");a[""+y(Me(y("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0O3s="),-3))]=n,a[""+y(Me(y("UFdQN1JHSEA="),-3))]=n,i[""+y(Me(y("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0O3s="),-3))]=n,xe(n,"bObjivY"),re(t,n),e.yejahd1484.w[13881]=n;var r=ie("div");ae(r,""+y(Me(y("U0pVc2dsRXNdRzNsZjVdeVxtSGxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1MbFNsRDtPNVVzZ203alNKVXNnbEVzXUczbGY1XXlcbVBsU2xEO081VXNnbTdqU0pVc2dsRXNdRzNsZjVdeVxtVGxTbEQ7TzVVc2dtN0A="),-3))),we(r.childNodes,function(t,i){ce(n,i),e.yejahCln.push(i)}),e.yejahCln.push(n)}function x(t){if(e.yejahd148tc.pm&&e.yejahf89Mobile&&(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1)){var n=a[""+y(Me(y("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbNEVR"),-3))];n&&t(n)}}function v(t){var n=ie("div");a[""+y(Me(y("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0PFRXVEBA"),-3))]=n,a[""+y(Me(y("UFdQN1JXUEA="),-3))]=n,i[""+y(Me(y("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0PFRXVEBA"),-3))]=n,Ue(n,"CISeAck "),re(t,n),e.yejahd1484.w[13893]=n;var r=ie("div");ae(r,""+y(Me(y("U0pVc2dsRXNdRzNsZjVdaWRKemxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1IbFNsRDtPNVVzZ203alNKVXNnbEVzXUczbGY1XXlcbUxsU2xEO081VXNnbTdqU0pVc2dsRXNdRzNsZjVdeVxtUGxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1UbFNsRDtPNVVzZ203QA=="),-3))),we(r.childNodes,function(t,i){ce(n,i),e.yejahCln.push(i)}),e.yejahCln.push(n)}b(13884,function(){var e=!0,t=n(""+y(Me(y("T248WVlITVZUWG9SWjVVa2dKSHdnNW9uXTVZM09ab25TVk1FWG87e0xvM2pPcDxsT1pRa2ZwVX0="),-3)),"");return e=e&&t},function(){r(d)}),b(13892,function(){var e=!0,t=n(""+y(Me(y("T248WVlITVZUWG9SWjVVa2dKSHdnNW9uXTVZM09ab25TVk1FWG87e0xvM0A="),-3)),"");return e=e&&t},function(){o(h)}),function(t){if(e.yejah2f6Flags.video){var i=n(""+y(Me(y("TDVreWVaWHdmcFltZ0pJeF01e29PW1F6ZTZVdmRaZ3JnRkR2TEY4Nl1bTWxnWjhxT1tNb1w2VWtlcGd2XVdIQA=="),-3)),"");i&&t(i)}}(f),function(t){if(e.yejah2f6Flags.video){var i=n(""+y(Me(y("ZVpJc2VsRC5MRjh8ZTZmalNsRHhlSkl8XTVYd1JGRHhlcFk2Znw0NmRaVXFdW1R3T1pReWVxVWtkWjhvZmxEdUxGcnZMSjRrZFo3alNsRHhmcDw2TEc3ak9we2tmcGdvT1dqak9xXXNdW2d6ZTZNM09bVXxcWlF1ZFo4cUxGdmpOakBA"),-3)),"");i&&t(i)}}(l),function(t){if(!(e.yejahf89Mobile||e.yejah2f6Flags.ncna&&e.yejahf89Mobile)){var i=n(""+y(Me(y("T3Fnb2ZwTTRlcGZ3ZjV3OGY1UXxcW0VvZmw0bWU1ODNcWm94XVtMQA=="),-3)),"");i&&t(i)}}(p),b(13886,function(){var e=!0,t=n(""+y(Me(y("TDZRcFs1a3Y="),-3)),"");return e=e&&t},function(){u(s)}),function(t){if(!(e.yejahf89Mobile||e.yejah2f6Flags.ncna&&e.yejahf89Mobile)){var i=n(""+y(Me(y("TDZNb1w1PHdlWll4XUpZfA=="),-3)),"");i&&t(i)}}(c),function(i){if(!e.yejahf89Mobile&&938<=(e.innerWidth||t.documentElement.clientWidth||t.body.clientWidth)&&(!e.yejah2f6Flags.ncna||!e.yejahf89Mobile&&938<=(e.innerWidth||t.documentElement.clientWidth||t.body.clientWidth))){var a=n(""+y(Me(y("TDU4a2dwb2xcWnt1XVo3dkw1NGtkWjdA"),-3)),"");a&&i(a)}}(R),b(13881,function(){var e=!0,t=a[""+y(Me(y("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbfUhA"),-3))];return ...
# var i=n[""+y(Me(y("V1lNaVk2TWtmS0VvZmpAQA=="),-3))];i?e(i):t(12352)}function d(i){var a=ie("div");n[""+y(Me(y("VzZZM2Y2VXxdWkl3WzM0Vg=="),-3))]=a,n[""+y(Me(y("UFdMfVFXTEA="),-3))]=a,t[""+y(Me(y("VzZZM2Y2VXxdWkl3WzM0Vg=="),-3))]=a;var r;xe(a,"XAUNSj"),r="#XAUNSj",re(i,a),e.yejahd1484.a[12352]=a;var d=[];(e.yejahd148tc.gn||e.yejahd148tc.ab)&&d.push(y("QURCTE9DSw==")),e.yejahd148tc.pm&&d.push("PM"),e.yejah2f6Flags.nc&&d.push("NC"),0===d.length&&d.push("NONE"),e.postMessage({from:nt,to:it,message:{type:"loadVideoTag",value:{positionId:12352,cssSelector:r,currentTrafficTypes:d}}}),X([{function:function(e,t){g(function(){e.classList.add("nolbl");var t=e.innerText.toLowerCase();t.indexOf("anzeige")>-1||t.indexOf("advertisement")>-1?e.classList.add("nolbl"):pe(e).height>=100&&e.classList.remove("nolbl")},500)}}],a,12352),e.yejahCln.push(a)}b(12353,function(){var t=!0,i=n[""+y(Me(y("VzZZM2Y2VXxdWkl3WzNdV1s0Z3xcW0V6XVtMQA=="),-3))];return t=t&&i,t=t&&t.getBoundingClientRect().top-e.innerHeight<=-150},function(){i(a,S)}),b(12352,function(){var t=!0,i=n[""+y(Me(y("V1lNaVk2TWtmS0VvZmpAQA=="),-3))];return t=t&&i,t=t&&t.getBoundingClientRect().top-e.innerHeight<=-150},function(){r(d,S)})}function q(i,a){function r(t,n,a,r){a||Ve(Me("22zzz1wudqvihupdunw1frp2lpdjh2X;Z8:itRn]MVf<uWeg5zp:oW;h|3RlljeO{ZM6JVfyq42"+e.yejahaf5Rnd+"]]S[[RJ<nuhNFvZ|OV;uNXN{WvwMqt|lIJHkS<{<UEen[;I1jli",-3),function(){if(!a){a=!0;var h=this;if(h.height<2)return void S(8694,n,!1);if(r==e.yejahaf5Rnd){var l=t,p=ie("div");i[""+y(Me(y("VG5vUFdEQEA="),-3))]=p,xe(p,"saTEfBdPd"),Ue(p,"uvQqdq ");var u=h;e.yejahce0Am[8694]&&(Y(e.yejahce0Am[8694]),e.yejahce0Am[8694]=!1),o(u,function(t,n){if(!e.yejah9a5Pc[8694]){t.preventDefault(),t.stopPropagation();for(var n=d(t,this),i=0;i<e.yejah7f5Oc.length;i++){var a=e.yejah7f5Oc[i];if(8694==a.p&&n.x>=a.x&&n.x<a.x+a.w&&n.y>=a.y&&n.y<a.y+a.h){if(a.u){var r=a.t.length>0?a.t:"_self";r=0==t.button&&t.ctrlKey?"_blank":r,Te(e,a.u,a.u,r,!0)}return}}var o=[Me("22zzz1wudqvihupdunw1frp2lpdjh2Y<3Q|FUPP<OYgSgjXL<Gz:lGq7NiFi}Y5G\\IGls{4h|P2"+e.yejahaf5Rnd+"OLZNeMSqwKsyMOPVL|yixe3ZYVfnRNU}{TmHilW6W5K[xlE1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2uq8J8{Knm5OZGMu7\\kZ]8Ke65;ifw4]Gi[nF:owyWJ3{2"+e.yejahaf5Rnd+"ME\\wLxuJYwWhYnPmj]UJJvI\\PhKU4UR9oNjNP]{|m|:lptG1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2nxmxzM6i<PSQrr|FiqZEhJLlYXqetXthvqIPk;}|zSKt2"+e.yejahaf5Rnd+"JTFzRxzRWj3OHmqvMfEt]F7VZRy9SkEoRYomU4YLL]xQzLS1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2[hSEs4j7Ky4E6y;Ns6{u{jh[kIN[lOy]94:k8UJWPUwu2"+e.yejahaf5Rnd+"VJU99LeTwGTNSWKKEUFzZ9yKh8o6zHwKKhj[qQ[Q{Som3nT1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2krtOJjq8}WvMjrGl}i8ZPiEtvfXNXX6TOusNs8nS5yZr2"+e.yejahaf5Rnd+"UW\\NkxrzM93o4V;okJV{;9sFYMqp8rSzN5OgLWEyL[j;6X:1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2ryVVvWmk;PPvqJqtVkFeLv6uOp9U:lt54uT;gF|5Ly972"+e.yejahaf5Rnd+"UFGKzoelq7{wU3QHTV[Q}Vv]FMsmn[gz3j]vvypp4IhpieS1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2{59}VeilkS}hj6jWe:8:R6|RN7HZHviKgzGhF5RKnqpo2"+e.yejahaf5Rnd+"P\\GHkF\\mrMIYwY{7kgpS5RX5UmEpQZvIOLiM|F;Fz:]hkZ71jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2nt\\RW6gryhlg<JTI|M{SO[WS5kUwhFMz{MlOevE6z:|k2"+e.yejahaf5Rnd+"H[ZusJvO<s;{YIyzgEFIRqLq:8uz8HV3x]mu|E6ZvX\\\\V[}1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2j4<nqsRpSXsRHUpt;8VRZH}4W:WuQ;h3R\\kpk|p|;Oih2"+e.yejahaf5Rnd+"KYO7Jl\\Yh6et|ReSm7rglsnKxNvRUQfRLvxYJroO]9oS}sv1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2f64tEYjH[KFN\\PXgNrQ:J888RyKNNG[zQ9ORnNo{ZU\\z2"+e.yejahaf5Rnd+"TPRe5q4wqFvYKRh55y3;Ni||zg;3O7lE8y<jr6QmVp97NnE1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2yVxgpFmG7Sku\\zpUGh<9tx7[x:o46g6gFS3;VhX33Fh]2"+e.yejahaf5Rnd+"XMIiS\\l5Hjz\\E<pr;TN3uKJRYu]ZsL<fomkWwJvnfK|sKfV1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh25Q[J5hRExp5]EP<VIMv7LnIfwxrTZfwRO[]evWWkgIgX2"+e.yejahaf5Rnd+"\\F[qKhQIuSi6w}rOtSp\\rNS4gWuRKV9szKGEYo{e7IP[\\vW1jli",-3)],h=[Me("22zzz1wudqvihupdunw1frp2lpdjh2h}:7L}zUkj|R[XWZzX[HRujSn[EFqGloemWzrFGefWN{2"+e.yejahaf5Rnd+"FTIX6[RU}3][}|N;EKmI7rk{W9ITKV;tl6nnFR:MvZ9:E4R1jli",-3),Me("22zzz1wudqvihup ...
# var o=[Me("22zzz1wudqvihupdunw1frp2lpdjh2K}UqQQuiY[z8pTTW:k7gm4]rsg;QlZi[|sl5Sg6VpKTM2"+e.yejahaf5Rnd+"IYI4etwLKpsF5[MjNeQE3RYRiTK9Ut:rIjn6IgEhw9\\{KGl1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2|iez{ZHxy\\MKNIsNj3iGZ\\NQvkKQ[tO}p\\JY;wUsG4K|2"+e.yejahaf5Rnd+"[]IMNWhT6Np\\N[MOqgTFP\\yX5U6F6{WZ:IeUvy3lj;VEMXW1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2ugx4uzTwMZjj5ev;HXGI5tNL6tmKqO3]74FtPYOs7yqk2"+e.yejahaf5Rnd+"[GE7T9Ol:Imp|y4loViu5:NokKn8neUje6:hYzelkKMeJsf1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2FxeGS|Qeo]G6}UKrEl7<gZe4|8;LIOn]khuyjqfrolPl2"+e.yejahaf5Rnd+"\\PSJit3VGLSY}jwW7qtUHRomKTGRSxrjs<fYI47E[9nZI6g1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2<ot9I}qKXUHern:p:6QM46xTWv}Pqx6L|SOxP;SZpxE72"+e.yejahaf5Rnd+"YJPtL[j3XMuroxnUpKi<JW<SQMU:Z9jvGMSwgEMMIknRwH{1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2FJ\\Jj8Fxxy]n|fGp:5NZSMHgVi4JLs]V5hV|M;ZIY}Pj2"+e.yejahaf5Rnd+"\\IX;Kwp7Ez]uUh:Prnz]QZX{3}WweSYsY;z4{FQjxMoKzje1jli",-3)],h=[Me("22zzz1wudqvihupdunw1frp2lpdjh2lI7[4TMjsS5uFE;8eH4U6m}L;8mQFk:GOxeLU:HryLj:2"+e.yejahaf5Rnd+"WGVXxNq}]:zRVt}yq}|Xeg:l3lkkLwqXWv34wlQi]TEtgT<1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2YLKnY[U5W3YFVzrL}lOeLgeL<RqEN5kRhnKYUo}r;<\\;2"+e.yejahaf5Rnd+"ZZ[u3}5PRZh{xhTZzi9iVxqJ5Kru3VlkY][}iYQ3v6Py;qg1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2FH7tr4hplkW4Wg;33hMpkSwWvPk}o}mMW7[zOsLO5We[2"+e.yejahaf5Rnd+"MQ\\eGwn3}N5X7lP{IjZ{\\I3]{KEvSqq5wVvQqr3:wzm\\MP<1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2HHFk8xMhi9n|r|N6\\UjxJ}5x9g5Nr<hrVVT4X|PpKws}2"+e.yejahaf5Rnd+"]KUrxQOORwINjfi7Kg9IhixV[ZokqeGysvo8J96OM\\FNHsh1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2[Qi}uhN73FrmMKp{nxQowumEOTh<JgJFe[yEfHN<Xuou2"+e.yejahaf5Rnd+"\\\\\\OrpKYZK6ly|9vejFH;Q]URFEJ|wjttZeXxtUrElhpPsG1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2ytXyHmGIU<Qo4ZU[O86z}SqX\\iU{tYRPeozP[|]f]:Zo2"+e.yejahaf5Rnd+"EPHvhzkYOV99tHvo<}7Ki{6\\:vFe|vZKHx<E5[Wi4IMyong1jli",-3)],l=o[1*f(6*n.y/this.offsetHeight)+f(1*n.x/this.offsetWidth)],p=h[1*f(6*n.y/this.offsetHeight)+f(1*n.x/this.offsetWidth)];Te(e,l,p,"_blank")}}),re(p,h),l.firstChild?ce(l.firstChild,p):re(l,p),e.yejahd1484.a[13883]=p,e.yejahCln.push(p),Ye(p,13883,Me("22zzz1wudqvihupdunw1frp2lpdjh2H9NuvSLNVx84ITRE5}Xqs<\\pj9;TVq3UQNu[\\tP{JfFw2"+e.yejahaf5Rnd+"RVKPN8;5x;\\5zlJill4F:mvmru6ZS{G\\V:VoHGXFmIwZOXy1jli",-3),function(){}),S(13883,n,!0)}}},function(){S(13883,n,!1)})}function m(t,i,a){if(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1){var r=n(""+y(Me(y("TDZRcGU1THw="),-3)),"");r?i(r,!t,!1,e.yejahaf5Rnd):a(13880,!t,!1)}else a(13880,!t,!1)}function g(t,n,a,r){a||Ve(Me("22zzz1wudqvihupdunw1frp2lpdjh2hmMxt5MqGJ6NG{fJzfKrXsrgM3Y:XYJHV:]fPEzz9T5Q2"+e.yejahaf5Rnd+"KPL}8gfLETWkxM[Io<sxNGEZElRn6fl\\XQkptFZNKnIpg{61jli",-3),function(){if(!a){a=!0;var h=this;if(h.height<2)return void S(13880,n,!1);if(r==e.yejahaf5Rnd){var l=t,p=ie("div");i[""+y(Me(y("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzt6UGwzelFEQEA="),-3))]=p,Ue(p,"OaESJRcYBX ");var u=h;e.yejahce0Am[13880]&&(Y(e.yejahce0Am[13880]),e.yejahce0Am[13880]=!1),o(u,function(t,n){if(!e.yejah9a5Pc[13880]){t.preventDefault(),t.stopPropagation();for(var n=d(t,this),i=0;i<e.yejah7f5Oc.length;i++){var a=e.yejah7f5Oc[i];if(13880==a.p&&n.x>=a.x&&n.x<a.x+a.w&&n.y>=a.y&&n.y<a.y+a.h){if(a.u){var r=a.t.length>0?a.t:"_self";r=0==t.button&&t.ctrlKey?"_blank":r,Te(e,a.u,a.u,r,!0)}return}}var o=[Me("22zzz1wudqvihupdunw1frp2lpdjh2XJlVSUvP59VO[PXuJnI5KluFZTZJ<K]oRr[jrsgQ{jUF2"+e.yejahaf5Rnd+"XZN4}wGIMJ}9p<vSQOfyR{ZY3Jr7ip9ny<V8TWVQOMhxsiW1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2I;vzhPsfpq4n[]HhILU8teMyrSnS|oQ<<koWZrVQe4f;2"+e.yejahaf5Rnd+"XHTY{UgVlvtgpFzM654V;XUKO\\p\\HT6uJ\\fgk;xvqZJEt\\N1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh266YXi9g<jtyGpEwxzjMLRRG9LM<]w;\\GOqMyz5n<hXGN2"+e.yejahaf5Rnd+"ZRE8g7J|e;8oOzvwQfQ8eLs6MRN9y]yYNLoO]x3KO3;;6rS1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2y<ymLKQfwgvTq{G}9L:I9Jj\\HzXEf5gTPnM}fspm}37v2"+e.yejahaf5Rnd+"HS[Kk;tonf83{qtRu|z5JtFgwffylQG69uHk|WlzFTZ}rvG1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh27Hn3rohG3ipg7t ...
# ;n&&(fe(n,"position","fixed",""),fe(n,"top","0",""))}},{selectorAll:"[id*=div-gpt-ad]",cssApply:{display:"none"}}],p,8695),Ye(p,8695,Me("22zzz1wudqvihupdunw1frp2lpdjh2ywj:Vm4gX\\QGRMSjQgZIiJ8SGMxGvT7FJTLEL<NmQeEZ2"+e.yejahaf5Rnd+"LJO4tfxMYigG{wgqF5h|V3OZWXTSrUss{[IVluISlIGQWny1jli",-3),function(){}),S(8695,n,!0)}}},function(){S(8695,n,!1)})}function I(t,n,i){var r=a[""+y(Me(y("WDN3XVs0TXNdNWszWzRnfFxbRXpdW0xA"),-3))];r?n(r,!t,!1,e.yejahaf5Rnd):i(8705,!t,!1)}function K(t,n,a,r){a||Ve(Me("22zzz1wudqvihupdunw1frp2lpdjh2\\v{]muT|huQsqZN}\\HWMm]IvISTxwLYisLuuVQyl[h}P2"+e.yejahaf5Rnd+"Z[Jg\\<i}jJwem;5MSu8Gnz4\\NMSSqG9Q\\3UjNIs6TXEz:l31jli",-3),function(){if(!a){a=!0;var h=this;if(h.height<2)return void S(8705,n,!1);if(r==e.yejahaf5Rnd){var l=t,p=ie("div");i[""+y(Me(y("WDN3XVs0TXNdNWszWzNda2VKe2xcWlF1"),-3))]=p,xe(p,"FaEAbVfei"),Ue(p,"AlFUkTUrj ");var u=h;e.yejahce0Am[8705]&&(Y(e.yejahce0Am[8705]),e.yejahce0Am[8705]=!1),o(u,function(t,n){if(!e.yejah9a5Pc[8705]){t.preventDefault(),t.stopPropagation();for(var n=d(t,this),i=0;i<e.yejah7f5Oc.length;i++){var a=e.yejah7f5Oc[i];if(8705==a.p&&n.x>=a.x&&n.x<a.x+a.w&&n.y>=a.y&&n.y<a.y+a.h){if(a.u){var r=a.t.length>0?a.t:"_self";r=0==t.button&&t.ctrlKey?"_blank":r,Te(e,a.u,a.u,r,!0)}return}}var o=[Me("22zzz1wudqvihupdunw1frp2lpdjh2q6q6VnvENvI|hzr\\[Pj}YsTFyR7Upm53y5TR88n6\\<Gj2"+e.yejahaf5Rnd+"]WQ:qp\\5Yf9JLRFPX6O9vV][WWMq3}Tl6YxjRQF4g[u}:yO1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2;TkqfkeYw6|YWho[ySFF}OJ;ehwzXuX\\Y\\S6wtURr7M32"+e.yejahaf5Rnd+"IFSfXf9Wrtf5XM\\|4||zvIYjx\\;|O[XJS|u]e<o<eVE7U]i1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh26K;q[mZ9ORy{mSXWPete{KoFOekpq5I|vn5<LxSJEnZ82"+e.yejahaf5Rnd+"YIFJPWQgl87pFRT{uMvKGO[Oy:gfMK<5Sy35suT74vt;OHL1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2];t;Js;IeITjmzUglQLQMX6[x}EvZMevZqhp;XQpZWNg2"+e.yejahaf5Rnd+"]Q\\64t[kFLoI}tLof9U4yZ;tl;4oHVE}iUhE<X3fV:9}RTw1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2yw;|i4IQH;[tp|IrlI7XsJj8fp|P9l\\rgmZ4TGFmHg8q2"+e.yejahaf5Rnd+"RY\\M6pj]\\<64{TKzYh4iqm5z8M]u]UY;rqOZtYKPx4oyzOY1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2jWev7i8qm]N;{sf9\\x4h;4Ff]qjo:QhzNm9ZV4wg8rqq2"+e.yejahaf5Rnd+"HQ[Fh8tRFQE{XiPg9r6JSEQSP;v9|kWuUY6R<{QJn;;u|mO1jli",-3)],h=[Me("22zzz1wudqvihupdunw1frp2lpdjh2vL<qP5YRnz9OmmnV{iHHQrWhl3Ex3zq9mnzfT66yzOiq2"+e.yejahaf5Rnd+"OSEiM{p\\snzW}JvRoUE5N|wRi{L8pMOK5YUgLRyRlkUE5PF1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2S7fi9<iSRE9OZ3PNHR7]JshJ8j9O|GInEuxF6wQKm5|r2"+e.yejahaf5Rnd+"Z]GgOQ:FKgK:T8Ul85yYrXMZm9\\YVQeMkIYgTNe;ZShzNVK1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2lS{QtL66z|<}v]QEUK9M4rLf;{{NfM][48OXI4KOvfMl2"+e.yejahaf5Rnd+"TOOXSnEh:SlKHfnOjeHX7\\GHxmtJfHu4qHqy:i]jejeh4jn1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2UXF:k5HyLlswIE9IH4Vl{SgswY5}xH7}3r3kPu9xwV}X2"+e.yejahaf5Rnd+"HSRrr7EkqFSJwst5oU\\wvim]F[okq7GF:76o73Yj6Vw8MQS1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh2[Rj<fzkXhSKK|[FlqguM\\lmWq[RVGZqWtRY9XORWPlS]2"+e.yejahaf5Rnd+"OEY4z|J}QtZwyNuFG[}ersO:Nfz7S6Hni8]4tTrO];iknKH1jli",-3),Me("22zzz1wudqvihupdunw1frp2lpdjh26P|e{7|9;Zl<kFKnSh|uytUsZ5GzjqMEKfw87Q\\yXZ;k2"+e.yejahaf5Rnd+"VOOXj<wVqUxO[JMiu<]o37[IR:K;KXpXzxJ}mVUtEuSopxM1jli",-3)],l=o[1*f(6*n.y/this.offsetHeight)+f(1*n.x/this.offsetWidth)],p=h[1*f(6*n.y/this.offsetHeight)+f(1*n.x/this.offsetWidth)];Te(e,l,p,"_blank")}}),re(p,h),re(l,p);try{var s=e.yejahd1484.a[8695];s&&s.parentNode.removeChild(s)}catch(l){}e.yejahd1484.a[8705]=p,X([{function:function(e,t){var n=e.querySelector("img");n&&(fe(n,"position","fixed",""),fe(n,"top","0",""))}},{selectorAll:"[id*=div-gpt-ad]",cssApply:{display:"none"}}],p,8705),Ye(p,8705,Me("22zzz1wudqvihupdunw1frp2lpdjh2UUNkFX366GFwyKoT{FF8kiOXxFZmNGvsE;v{;64srl{82"+e.yejahaf5Rnd+"WQYlusZ\\HUX:RvpKzh;UfxgWUQ[fP6IhHq:yqjzQNjjF:r41jli",-3),function(){}),S(8705,n,!0)}}},function(){S(8705,n,!1)})}function L(t,i,a){var r=n(""+y(Me(y("TDZRcGdKTHs="),-3)),"");r?i(r,!t,!1,e.yejahaf5Rnd):a(8939,!t,!1)}function J(t,n,a,r){a||Ve(Me("22zzz1wudqvihupdunw1frp2lpdjh2iF|jIlWNL6wQXwlJ]9wTMO5QTmey4{XJHsTm:R[KzuKy2"+e.yejahaf5Rnd+"IEExTgfSWnnPJ9lH ...
# e.yejahsc.crt?ge(Me("22zzz1wudqvihupdunw1frp2lpdjh2w{GzKvxMyP6E\\3KeIP7zliSQqPW{pUsxUt};E4vnExsq2"+e.yejahaf5Rnd+"TJNOJFzwSMP8o7Y5T4WrYZlIKm[rH\\pNUlirse;ePkO|mRU1jli",-3),i,i):ge(Me("22zzz1wudqvihupdunw1frp2lpdjh2LHzqMgfs<X4RS\\mU6QWXgKgEKZIeGn9k:z6||IoYtRKl2"+e.yejahaf5Rnd+"[ZL\\p:z|<LGfWWTLzGWp8{zt]P7:LVVWwFWui:NnfKIx:6u1jli",-3),i,i)};a(p)}else e.yejah2f6Flags.aa&&e.yejah2f6Flags.aa.done&&e.yejah2f6Flags.aa.enabled?ge(Me("22zzz1wudqvihupdunw1frp2lpdjh2w{GzKvxMyP6E\\3KeIP7zliSQqPW{pUsxUt};E4vnExsq2"+e.yejahaf5Rnd+"TJNOJFzwSMP8o7Y5T4WrYZlIKm[rH\\pNUlirse;ePkO|mRU1jli",-3),i,i):ge(Me("22zzz1wudqvihupdunw1frp2lpdjh2LHzqMgfs<X4RS\\mU6QWXgKgEKZIeGn9k:z6||IoYtRKl2"+e.yejahaf5Rnd+"[ZL\\p:z|<LGfWWTLzGWp8{zt]P7:LVVWwFWui:NnfKIx:6u1jli",-3),i,i)}else if(r){if(e.yejah2f6Flags.ncrld&&!e.yejah2f6Flags.glblrld&&"function"==typeof $){e.yejah2f6Flags.glblrld=!0;var d=g(function(){m(d),$()},6e4)}ge(Me("22zzz1wudqvihupdunw1frp2lpdjh2R4fsXosSF4YHS9wYqRjzSG[Qr{jsilNoUYjmo|XYqv8E2"+e.yejahaf5Rnd+"V\\Xr{vP9M;ystQTHU[sG]:3j{h4HSLy9{jS[umLYs]4E{li1jli",-3),i,i),e.yejah2f6Flags.ncna=!0}else et=!1}()}else et=!1},r=!1;if(e.yejah2f6Flags.fnc)r=!0,a();else if(e.yejah2f6Flags.tcf){var d=e.yejah2f6Flags.tcf;r=w(d.purpose.consents)&&!T(d.purpose)&&("tcloaded"==d.eventStatus||"useractioncomplete"==d.eventStatus),a()}else try{var o=function(t,n){try{r=w(t.purpose.consents)&&!T(t.purpose)&&("tcloaded"==t.eventStatus||"useractioncomplete"==t.eventStatus),e.yejah2f6Flags.tcf=t}catch(e){r=!1}a()};"undefined"!=typeof __tcfapi?__tcfapi("addEventListener",2,o):a()}catch(e){a()}}function K(t){var n=function(){};"1"==t&&Ve(Me("22zzz1wudqvihupdunw1frp2lpdjh28i;ekJU:nY:VFjx:5YTPFeiw5iu8w[p4|z<QLOnHEnfS2"+e.yejahaf5Rnd+"\\HXJ3HLojlO96pmrH<h76p7zk[{s]GlrzrmE6KYHEEggJk{1jli",-3),n,n),"2"==t&&Ve(Me("22zzz1wudqvihupdunw1frp2lpdjh2Tm6G]MIvz:QjPGF]sG[gf|og6tyugwXmrUPqEu4rInJL2"+e.yejahaf5Rnd+"QPH4MwGzR6}M3:iK<]JnF|JijNOw:rjk5YhVvZMsWye3txO1jli",-3),n,n),"3"==t&&Ve(Me("22zzz1wudqvihupdunw1frp2lpdjh257kQZENE{ig\\3Jt:Qh5uJnWxx:iEq<6NF4FwQ<7OYr][2"+e.yejahaf5Rnd+"[RXgYRV;qgtvW6lq{RqnX84vyngjE7s66UqVYrnzsiTLLKp1jli",-3),n,n),"4"==t&&Ve(Me("22zzz1wudqvihupdunw1frp2lpdjh2s4KKg3P\\[:KHn[6p5\\eNy3|NOnESWE<9Iho[[iGWx4ge2"+e.yejahaf5Rnd+"OWNutu3YfhX5vvFE\\5kf\\G7Qr9IJiG7wpne}|NfrrTWjsyY1jli",-3),n,n)}function L(){e.yejahd148d3++,e.yejahd148d3==e.yejahd1481.length&&e.yejahd1482.length==e.yejahd148d3&&(e.yejahd148tc.ab=!0),e.yejahd148d3==e.yejahd1481.length&&(e.yejahd148tc.abd=!0),B()}function J(){return document.cookie.replace(/(?:(?:^|.*;\s*)xdefccpm\s*\=\s*([^;]*).*$)|^.*$/,"$1")}function B(){var t="";if(!e.yejah2f6Flags.nopmcache)try{t=J()}catch(e){}e.yejah2f6Flags.pmcache=!0,""!=t&&(e.yejahd148tc.pmd=!0,"yes"===t&&(e.yejahd148tc.pm=!0),e.yejah2f6Flags.pmcache=!1),e.yejah2f6Flags.pmasync&&(e.yejahd148tc.gn||e.yejahd148tc.ab)&&I(e.yejahd148tc.pm,e.yejahd148tc.gn||e.yejahd148tc.ab),e.yejahd148tc.abd&&e.yejahd148tc.pmd&&e.yejahd148tc.gnd&&I(e.yejahd148tc.pm,e.yejahd148tc.gn||e.yejahd148tc.ab)}function D(){A()}function A(){if(!e.yejahe09Detect){e.yejahe09Detect=!0,e.yejahd148tc.ab=!1,e.yejahd148tc.abd=!1,e.yejahd148tc.gn=!1,e.yejahd148tc.gnd=!1;var t=x();e.yejahf89Mobile=t.match(/iPad/i)||t.match(/iPhone/i)||t.match(/iPod/i)||t.match(/Android/i),e.yejahd1481=[],e.yejahd148o1=[],e.yejahd148o1a=[],e.yejahd148o2=[],e.yejahd148o3=[],e.yejahd148o3a=[],e.yejahd1482=[],e.yejahd148d3=0;try{0!=e.yejahd148d3&&(e.yejahd148d3=0)}catch(e){return void K(4)}e.yejahd1484={},e.yejahd1484.a={},e.yejahd1484.w={},e.yejahd1484.f={},e.yejahd1484.cb=!1,e.yejahd1484.r={},e.yejahd1485={},e.yejahd1485.e=0,e.yejahd1485.s=0,e.yejah560ij=!1,e.yejah2f6Flags.pd4=yejahd1484;var n=(new Date).getTime(),i=function(){if(Ze(this))"function"==typeof EJJKJTrkFailed&&EJJKJTrkFailed(Me("22zzz1wudqvihupdunw1frp2lpdjh2nWtnhNKyQSO9iL5TjSv:u6G4l\\wKePUJu;GSi6FHnK9S2"+e.yejahaf5Rnd+"TY]5XqH}yI4Kgj4\\FwhO|[EORvjG8]JN<rn[qqWf}FS3Ijt1jli",-3),(new Date).getTime()-n);else if(e.yejah2f6Flags.bl7fbUp&&Ge(this)){var t=new XMLHttpRequest;t[ ...
# r.style.backgroundImage="url("+g+")";break;case"script":w=c.createElement("script"),Array.from(r.attributes).forEach(function(e){de(w,e.nodeName,"src"===e.nodeName?g:e.nodeValue)}),w.onload=function(){Ne(r,"load")},v(w,"error",a),E=r.parentNode,E&&r.isConnected||(E=c.head),re(E,w),w.src=l,w.adf_actual_src=g,w.adf_rewritten=!0;break;case"iframe":/imasdk.googleapis.com/.test(l)&&(g+="&="+n(l,!0)),r.contentWindow.location.replace(g);break;case"video":if(r.src!==l)return;v(r,"canplay",function(){fe(r,"display","block","important"),x=!0,r.adf_rewritten=!1,r.play()}),r.preload="auto",r.src=g;break;case"css":r.href=g}},0)}}else if("iframe"===p&&"load"===u&&r.contentDocument){$(r);var R=o("hiddenElement",!1);R&&r.closest(R)||W(200,15,r,p)}}}}}}function _(e){var t=e.target;!t.adf_rewritten&&i(t.src)&&q(t,"iframe",t.src)&&(e.stopImmediatePropagation(),t.removeEventListener("load",_,!0),v(t,"error",C,!0),Ne(t,"error"))}function $(e){i(e.src)?v(e,"load",_,!0):e.contentDocument?(le(e.contentDocument),v(e,"load",ee,!0)):h(function(){e.contentDocument?le(e.contentDocument):v(e,"load",ee,!0)},0)}function ee(e){try{var t=e.target;t.removeEventListener("load",ee,!0),i(t.src)?_(e):t.contentDocument&&(P(t.contentDocument),le(t.contentDocument))}catch(e){}}function le(t){if(!t.adf_rewritten){t.adf_rewritten="main";var n=e;n!==t.defaultView&&(t.adf_rewritten="iframe",n=t.defaultView),p(t,"hiddenElement",function(e){W(200,15,e)}),p(t,"anchor",function(e){R(e)}),t.querySelectorAll("script").forEach(function(e){P(e)});var i=e.Function.bind,r=i.bind(i),d=function(e,t){return new(r(e,null).apply(null,t))};n.Image=function(e){function n(){var n=d(e,arguments);return D()?(n.orgnl_script=t.currentScript,P(n),n):n}return n.prototype=e.prototype,n}(n.Image),function(e){n.XMLHttpRequest.prototype.open=function(){var t=this;try{if(!arguments[0]||!arguments[1]||/^\/[^\/]/.test(arguments[1])||!q(t,"xhr",arguments[1])||t.adf_rewritten||t[Se])return;t.adf_xhrOpenArgs=arguments,t.adf_tagName="xhr",t.adf_req_headers=[]}finally{e.apply(t,arguments)}}}(n.XMLHttpRequest.prototype.open),function(e){n.XMLHttpRequest.prototype.setRequestHeader=function(){var t=this;try{if("xhr"!==t.adf_tagName||t.adf_rewritten||t[Se]||!(t.adf_req_headers instanceof n.Array)||!D())return;t.adf_req_headers.push(arguments)}finally{e.apply(t,arguments)}}}(n.XMLHttpRequest.prototype.setRequestHeader),function(e){n.XMLHttpRequest.prototype.send=function(){var t=this;try{if("xhr"!==t.adf_tagName||t.adf_rewritten||t[Se]||t.hasOwnProperty("adf_body")||!D())return;if(t.orgnl_error_hdlr=t.onerror,t.onerror=null,t.orgnl_readystatechange_hdlr=t.onreadystatechange,t.onreadystatechange=function(e){return 4!==t.readyState?void("function"==typeof t.orgnl_readystatechange_hdlr&&t.orgnl_readystatechange_hdlr(e)):/^[23]/.test(t.status)?(e.adf_event_type="load",C(e),void("function"==typeof t.orgnl_readystatechange_hdlr&&t.orgnl_readystatechange_hdlr(e))):(e.adf_event_type="error",void C(e))},t.adf_body=arguments[0],Q({type:"xhr",requestMethod:t.adf_xhrOpenArgs[0],url:t.adf_xhrOpenArgs[1]},"network"))return void A(null,t);P(t)}catch(e){S(t)}finally{e.apply(t,arguments)}}}(n.XMLHttpRequest.prototype.send),function(e){n.open=function(){function t(){if(i&&!i.opener||l>100){try{i.opener=n}catch(e){}m(f)}else l+=1}var i;try{if(!D()||!$e)return void(i=e.apply(n,arguments));var r=arguments[0],d=a(),o=h(function(){J({name:"clickRecovery",timing:3e3})},3e3);v(n,"message",function(e){e.data.message&&"ping"===e.data.message&&e.data.tabId&&e.data.tabId===d&&(clearTimeout(o),e.source.postMessage({message:"pong",targetURL:r,tabId:d,video:!0},"*"))},!0),i=e.apply(n,[ve+"#"+d]);var f,l=0;try{i.opener=n}catch(e){}f=g(t,1)}catch(t){i=e.apply(n,arguments)}finally{return i}}}(n.open),function(t){e.yejah2f6Flags&&e.yejah2f6Flags.fetchRecoveryOff||(n.fetch=function(){var e=arguments;try{var i={type:"xhr",requestMethod:e&&e[1]&&e[1].method?e[1].method:"GET",url:e&&e[0]?e[0]:""};return D()&&i.url&&!M(i,"network")?(i.url=j(i.url),z(i. ...
# </script>
# <div class="werbung werbung-header">
# <!-- Start GPT Tag -->
# <script>
#                   window.googletag = window.googletag || {cmd: []};
#                   googletag.cmd.push(function() {
#                     googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600], [120, 600]], "div-gpt-ad-1621527521939-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600], [120, 600]], "div-gpt-ad-1621528123398-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90], [300, 250]], "div-gpt-ad-1621528173524-0")
#                     .addService(googletag.pubads());
#                      googletag.pubads().enableLazyLoad({
#                         fetchMarginPercent: 500,
#                         renderMarginPercent: 200,
#                         mobileScaling: 2.0});
#                     googletag.pubads().setCentering(true);
#                     googletag.pubads().disableInitialLoad();
#                     googletag.pubads().enableSingleRequest();
#                     googletag.pubads().setTargeting("cg1", ["marktwertetop"]);
#                     googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                     googletag.enableServices();
#                   });
#                 </script>
# <!-- End GPT Tag -->
# </div></link></link></head>
# <body class="" data-cmp-layer-id="910164" data-tm-tld="com" itemscope="" itemtype="http://schema.org/WebPage">
# <div id="main">
# <div class="werbung-skyscraper-container">
# <div class="werbung werbung-skyscraper"><div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });</script>
# </div> </div>
# <div class="werbung-skyscraperbtf-container">
# <div class="werbung werbung-skyscraperbtf"><div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });</script>
# </div> </div>
# <header class="tm-header">
# <div class="tm-header__box">
# <a href="/">
# <img alt="Transfermarkt" class="icon-logo" height="62" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="156"/>
# </a>
# <tm-domainswitcher open-list="false" tld="com"></tm-domainswitcher>
# <div class="tm-header__social-box">
# <a class="header__social-link" href="https://www.facebook.com/Transfermarkt.global" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/fb_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link header__social-link--twitter" href="https://twitter.com/TMuk_news" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank">
# <img class="header__icon header__icon--twitter" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/twitter.svg" width="20"/>
# </a>
# <a class="header__social-link" href="http://instagram.com/transfermarkt_official" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/instagram_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="/intern/rssguide" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/rss_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="https://www.tiktok.com/@transfermarkt" onclick="tmEvent('SM-Icons_Header','click','Tiktok');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/tiktokRebrush.svg" width="20"/>
# </a>
# </div>
# <div class="tm-header__input-wrapper" id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="tm-header__form" id="schnellsuche" name="schnellsuche">
# <input autocorrect="off" class="tm-header__input--search-field" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=""/>
# <input alt="search" class="tm-header__input--search-send" type="submit" value=""/>
# </form>
# <a class="tm-header__search-detail" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="To the player detail search">
# <img alt="search" class="tm-header__icon-detail-search" height="26" src="https://tmsi.akamaized.net/icons/search_icon_plus_blue_white.svg" width="26"/>
# </a>
# </div>
# </div>
# <nav class="main-navbar navihalter">
# <ul class="main-navbar__container megamenu_dark_bar megamenu_dark" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <li class="main-navbar__list" data-nav-group="news">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('News','click','menu');
# ">
#             News        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="transfers">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#             Transfers &amp; rumours        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list aktiv" data-nav-group="marktwerte">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Marktwerte','click','menu');
# ">
#             Market values        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="wettbewerbe">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#             Competitions        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="foren">
# <a class="main-navbar__list-title tm-main-nav-el" href="/uebersicht/index/forum/com" onclick="tmEvent('Foren','click','menu');
# ">
#             Forums                    </a>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="meintm">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('MeinTM','click','menu');
# ">
#             My TM        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list">
# <a class="main-navbar__list-title tm-main-nav-el live-navilink" href="/ticker/index/live" onclick="tmEvent('Live','click','menu');
# ">
# ...
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         End of loan                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Almamy Touré" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/216181-1700140427.jpg?lm=1" title="Almamy Touré"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/almamy-toure/profil/spieler/216181" title="Almamy Touré">Almamy Touré</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/almamy-toure/transfers/spieler/216181/transfer_id/4731842?from=neustetransfersbox" title="Almamy Touré">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/1-fc-kaiserslautern/transfers/verein/2" title="1.FC Kaiserslautern"><img alt="1.FC Kaiserslautern" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/2.png?lm=1580920736" title="1.FC Kaiserslautern"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/almamy-toure/transfers/spieler/216181/transfer_id/4731842?from=neustetransfersbox" title="Almamy Touré">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2024                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Jefté Betancor" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/198015-1661769903.jpg?lm=1" title="Jefté Betancor"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/jefte-betancor/profil/spieler/198015" title="Jefté Betancor">Jefté Betancor</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Forward                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/cfr-cluj/transfers/verein/7769" title="CFR Cluj"><img alt="CFR Cluj" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/7769.png?lm=1414777942" title="CFR Cluj"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/jefte-betancor/transfers/spieler/198015/transfer_id/4731376?from=neustetransfersbox" title="Jefté Betancor">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/jefte-betancor/transfers/spieler/198015/transfer_id/4731376?from=neustetransfersbox" title="Jefté Betancor">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="André Ayew" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/45403-1668429304.jpg?lm=1" title="André Ayew"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/andre-ayew/profil/spieler/45403" title="André Ayew">André Ayew</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Left Winger                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/andre-ayew/transfers/spieler/45403/transfer_id/4727561?from=neustetransfersbox" title="André Ayew">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/ac-le-havre/transfers/verein/738" title="Le Havre AC"><img alt="Le Havre AC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/738.png?lm=1408780648" title="Le Havre AC"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/andre-ayew/transfers/spieler/45403/transfer_id/4727561?from=neustetransfersbox" title="André Ayew">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2024                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Kristian Hlynsson" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/694186-1664796563.jpg?lm=1" title="Kristian Hlynsson"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/kristian-hlynsson/profil/spieler/694186" title="Kristian Hlynsson">K. Hlynsson</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Attacking Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/ajax-amsterdam-ii/transfers/verein/8817" title="Ajax Amsterdam U21"><img alt="Ajax Amsterdam U21" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/8817.png?lm=1657054414" title="Ajax Amsterdam U21"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/kristian-hlynsson/transfers/spieler/694186/transfer_id/4722282?from=neustetransfersbox" title="Kristian Hlynsson">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/ajax-amsterdam/transfers/verein/610" title="Ajax Amsterdam"><img alt="Ajax Amsterdam" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/610.png?lm=1657054414" title="Ajax Amsterdam"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/kristian-hlynsson/transfers/spieler/694186/transfer_id/4722282?from=neustetransfersbox" title="Kristian Hlynsson">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2026                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="content-link" href="/statistik/letztetransfers">Complete list</a>
# </div>
# <div class="werbung werbung-rectangle2"><div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });</script>
# </div> </div>
# </div>
# <div class="werbung werbung-fullsize_contentad"><div id="div-gpt-ad-1621528173524-0" style="min-width: 728px; min-height: 90px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528173524-0"); });</script>
# </div> </main>
# <footer>
# <div class="tm-footer">
# <a class="tm-footer__logo" href="/">
# <img alt="Transfermarkt" height="33" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" width="80"/>
# </a>
# <ul class="tm-footer__links">
# <li class="tm-footer__links-item">
# <a href="/intern/impressum">
#           Legal notice      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/web/datenschutz">
#           Data protection      </a>
# </li>
# <li class="tm-footer__links-item">
# <a class="cmp-link" href="javascript:void(0)">
#           Privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/anb">
#           General terms of use      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/tmteam">
#           The TM team      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/faq">
#           FAQ      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/fehlermelden">
#           Found a mistake?      </a>
# </li>
# </ul>
# </div>
# </footer>
# <div id="menue_overlay"></div>
# </div>
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "co":""
# }
#     </script>
# <script type="module">
#         var defaultOptions = {
#             tracking: !0,
#             refreshAds: !0
#         };
#         export var refreshAd = function() {
#             var e, n;
#             [ASCDP.hasOwnProperty("adS"), null === (e = ASCDP.adS) || void 0 === e ? void 0 : e.hasOwnProperty("reloadAds"), "function" == typeof(null === (n = ASCDP.adS) || void 0 === n ? void 0 : n.reloadAds)].every(function(e) {
#                 return e
#             }) && ASCDP.adS.reloadAds()
#         };
#         export var TmTrackingAndAds = function(e, n) {
#             void 0 === n && (n = defaultOptions);
#             var r = ["tabelle", "reiter", "forum"].includes(e) ? e : "";
#             n.tracking && (gtag("event", "page_view", {
#                 page_path: "/jsContent" + window.location.pathname
#             }), sendIvwData(r)), n.refreshAds && "undefined" != typeof ASCDP && refreshAd()
#         };
#         window.tmTrackingAndAds = function(e, n) {
#             return TmTrackingAndAds(e, n)
#         };
#     </script>
# <script type="text/javascript">
#             const iommInterval = setInterval(() => {
#                 if (typeof IOMm === 'function') {
#                     IOMm('configure', {
#                         st: iam_data.st,
#                         dn: 'data-84a0f3455d.transfermarkt.com',
#                         mh: 5
#                     });
#                     IOMm('pageview', {
#                         cp: iam_data.cp,
#                         co: iam_data.co
#                     });
#                     clearInterval(iommInterval);
#                 }
#             }, 250);
#         </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script>
#             $(function() {
#                 var cnt = $('div.large-4.columns').length;
#                 if (cnt == 1) {
#                     var sidebarDiv = document.querySelector('div.large-4.columns');
#                     if (sidebarDiv !== null) {
#                         $('#werbung_recommender_sidebar_wrapper').appendTo(sidebarDiv);
#                         $('#werbung_recommender_sidebar_wrapper').show();
#                     }
#                 }
#             });
#         </script>
# <div id="werbung_recommender_sidebar_wrapper" style="display: none;">
# <div class="box" id="recommender_sidebar">
# <div class="OUTBRAIN" data-widget-id="SL_DT_SB"></div>
# <tm-consent embed="PHNjcmlwdCB0eXBlPSJ0ZXh0L2phdmFzY3JpcHQiIGFzeW5jPSJhc3luYyIgc3JjPSIvL3dpZGdldHMub3V0YnJhaW4uY29tL291dGJyYWluLmpzIj48L3NjcmlwdD4=" no-checkbox="" type="outbrain"></tm-consent>
# </div>
# </div>
# <script defer="" src="https://tmsi.akamaized.net/js/custom-element-globals/tm-global-elements.esm.js" type="module"></script><script defer="" nomodule="" src="https://tmsi.akamaized.net/js/custom-element-globals/tm-global-elements.js"></script> <tm-consent embed="..." no-checkbox="" type="nielsen">
# </tm-consent>
# <script defer="" src="https://tmsi.akamaized.net/js/svelte-components-2d3db030/consent/bundle.js"></script><script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1700238204" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/tm-menu.min.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/vendors.min.js?lm=1700238203" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# function skyscraperSwitch() {
#                const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	var loginUrl='/profil/login';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function sendIvwData(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "co":""
# }
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "co":""
# }
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "co":""
# }
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "co":""
# }
#
#     }
#     if(typeof IOMm === 'function') {
#         IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#     }
# }
# window.articlemetadata = {
#     type: "static",
#     assetid: 'statistik-global',
#     section:  'statistik',
#     segA: iam_data.cp,
#     segB: "CPI",
#     segC: "",
#     subbrand: "c18"
#     };
#
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page','afterAjaxUpdate':function() {window.LazyLoadInstance.update(); tmTrackingAndAds(); document.dispatchEvent(new CustomEvent("tmInitTooltip"));}});
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
player_info = soup.find_all('tr', class_=['odd', 'even'])
print(player_info[0])
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Erling Haaland" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/418560-1694590614.jpg?lm=1" title="Erling Haaland"/></a></td><td class="hauptlink"><a href="/erling-haaland/profil/spieler/418560" title="Erling Haaland">Erling Haaland</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">23</td><td class="zentriert"><img alt="Norway" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/125.png?lm=1520611569" title="Norway"/></td><td class="zentriert"><a href="/manchester-city/startseite/verein/281" title="Manchester City"><img alt="Manchester City" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/281.png?lm=1467356331" title="Manchester City"/></a></td><td class="rechts hauptlink"><a href="/erling-haaland/marktwertverlauf/spieler/418560">€180.00m</a> </td></tr>

# %%
print(len(player_info))
# Out:
# 25

# %%
number, name, position, age, nation, team, value = [], [], [], [], [], [], []

for info in player_info:
    player = info.find_all("td")
    number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5].text)
    nation.append(player[6].img['alt'])
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip())

# %%
for info in player_info:
    player = info.find_all("td")
    print(player[8])
# Out:
# <td class="rechts hauptlink"><a href="/erling-haaland/marktwertverlauf/spieler/418560">€180.00m</a> </td>
# <td class="rechts hauptlink"><a href="/kylian-mbappe/marktwertverlauf/spieler/342229">€180.00m</a> </td>
# <td class="rechts hauptlink"><a href="/jude-bellingham/marktwertverlauf/spieler/581678">€150.00m</a> </td>
# <td class="rechts hauptlink"><a href="/vinicius-junior/marktwertverlauf/spieler/371998">€150.00m</a> </td>
# <td class="rechts hauptlink"><a href="/bukayo-saka/marktwertverlauf/spieler/433177">€120.00m</a> </td>
# <td class="rechts hauptlink"><a href="/victor-osimhen/marktwertverlauf/spieler/401923">€120.00m</a> </td>
# <td class="rechts hauptlink"><a href="/jamal-musiala/marktwertverlauf/spieler/580195">€110.00m</a> </td>
# <td class="rechts hauptlink"><a href="/phil-foden/marktwertverlauf/spieler/406635">€110.00m</a> </td>
# <td class="rechts hauptlink"><a href="/harry-kane/marktwertverlauf/spieler/132098">€110.00m</a> </td>
# <td class="rechts hauptlink"><a href="/pedri/marktwertverlauf/spieler/683840">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/rodrygo/marktwertverlauf/spieler/412363">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/lautaro-martinez/marktwertverlauf/spieler/406625">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/federico-valverde/marktwertverlauf/spieler/369081">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/declan-rice/marktwertverlauf/spieler/357662">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/rodri/marktwertverlauf/spieler/357565">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/moises-caicedo/marktwertverlauf/spieler/687626">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/gavi/marktwertverlauf/spieler/646740">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/eduardo-camavinga/marktwertverlauf/spieler/640428">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/aurelien-tchouameni/marktwertverlauf/spieler/413112">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/rafael-leao/marktwertverlauf/spieler/357164">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/frenkie-de-jong/marktwertverlauf/spieler/326330">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/martin-odegaard/marktwertverlauf/spieler/316264">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/florian-wirtz/marktwertverlauf/spieler/598577">€85.00m</a> </td>
# <td class="rechts hauptlink"><a href="/bruno-guimaraes/marktwertverlauf/spieler/520624">€85.00m</a> </td>
# <td class="rechts hauptlink"><a href="/khvicha-kvaratskhelia/marktwertverlauf/spieler/502670">€85.00m</a> </td>

# %%
df = pd.DataFrame(
    {
        "number": number,
        "name":name,
        "position":position,
        "age":age,
        "nation":nation,
        "team":team,
        "value":value
    }
)
df
# Out:
#    number                   name            position age       nation  \
# 0       1         Erling Haaland      Centre-Forward  23       Norway
# 1       2          Kylian Mbappé         Left Winger  24       France
# 2       3        Jude Bellingham  Attacking Midfield  20      England
# 3       4        Vinicius Junior         Left Winger  23       Brazil
# 4       5            Bukayo Saka        Right Winger  22      England
# 5       6         Victor Osimhen      Centre-Forward  24      Nigeria
# 6       7          Jamal Musiala  Attacking Midfield  20      Germany
# 7       8             Phil Foden         Left Winger  23      England
# 8       9             Harry Kane      Centre-Forward  30      England
# 9      10                  Pedri    Central Midfield  20        Spain
# 10     11                Rodrygo        Right Winger  22       Brazil
# 11     12       Lautaro Martínez      Centre-Forward  26    Argentina
# 12     13      Federico Valverde    Central Midfield  25      Uruguay
# 13     14            Declan Rice  Defensive Midfield  24      England
# 14     15                  Rodri  Defensive Midfield  27        Spain
# 15     16         Moisés Caicedo  Defensive Midfield  22      Ecuador
# 16     17                   Gavi    Central Midfield  19        Spain
# 17     18      Eduardo Camavinga    Central Midfield  21       France
# 18     19    Aurélien Tchouaméni  Defensive Midfield  23       France
# 19     20            Rafael Leão         Left Winger  24     Portugal
# 20     21        Frenkie de Jong    Central Midfield  26  Netherlands
# 21     22        Martin Ødegaard  Attacking Midfield  24       Norway
# 22     23          Florian Wirtz  Attacking Midfield  20      Germany
# 23     24        Bruno Guimarães  Defensive Midfield  26       Brazil
# 24     25  Khvicha Kvaratskhelia         Left Winger  22      Georgia
#
#                    team     value
# 0       Manchester City  €180.00m
# 1   Paris Saint-Germain  €180.00m
# 2           Real Madrid  €150.00m
# 3           Real Madrid  €150.00m
# 4            Arsenal FC  €120.00m
# 5            SSC Napoli  €120.00m
# 6         Bayern Munich  €110.00m
# 7       Manchester City  €110.00m
# 8         Bayern Munich  €110.00m
# 9          FC Barcelona  €100.00m
# 10          Real Madrid  €100.00m
# 11          Inter Milan  €100.00m
# 12          Real Madrid  €100.00m
# 13           Arsenal FC  €100.00m
# 14      Manchester City  €100.00m
# 15           Chelsea FC   €90.00m
# 16         FC Barcelona   €90.00m
# 17          Real Madrid   €90.00m
# 18          Real Madrid   €90.00m
# 19             AC Milan   €90.00m
# 20         FC Barcelona   €90.00m
# 21           Arsenal FC   €90.00m
# 22  Bayer 04 Leverkusen   €85.00m
# 23     Newcastle United   €85.00m
# 24           SSC Napoli   €85.00m

# %%
df.to_csv('tranfermarkt25.csv', index=False)
