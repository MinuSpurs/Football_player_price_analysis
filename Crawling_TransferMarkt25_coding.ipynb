# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"}

url = "https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop"

r = requests.get(url, headers = headers)
r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(r.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script type="text/javascript">
#     !function () { var e = function () { var e, t = "__tcfapiLocator", a = [], n = window; for (; n;) { try { if (n.frames[t]) { e = n; break } } catch (e) { } if (n === window.top) break; n = n.parent } e || (!function e() { var a = n.document, r = !!n.frames[t]; if (!r) if (a.body) { var i = a.createElement("iframe"); i.style.cssText = "display:none", i.name = t, a.body.appendChild(i) } else setTimeout(e, 5); return !r }(), n.__tcfapi = function () { for (var e, t = arguments.length, n = new Array(t), r = 0; r < t; r++)n[r] = arguments[r]; if (!n.length) return a; if ("setGdprApplies" === n[0]) n.length > 3 && 2 === parseInt(n[1], 10) && "boolean" == typeof n[3] && (e = n[3], "function" == typeof n[2] && n[2]("set", !0)); else if ("ping" === n[0]) { var i = { gdprApplies: e, cmpLoaded: !1, cmpStatus: "stub" }; "function" == typeof n[2] && n[2](i) } else a.push(n) }, n.addEventListener("message", (function (e) { var t = "string" == typeof e.data, a = {}; try { a = t ? JSON.parse(e.data) : e.data } catch (e) { } var n = a.__tcfapiCall; n && window.__tcfapi(n.command, n.version, (function (a, r) { var i = { __tcfapiReturn: { returnValue: a, success: r, callId: n.callId } }; t && (i = JSON.stringify(i)), e.source.postMessage(i, "*") }), n.parameter) }), !1)) }; "undefined" != typeof module ? module.exports = e : e() }();
# </script>
# <script>
# window._sp_ = {
#     config: {"accountId":1254,"propertyId":7427,"gdpr":{"consentLanguage":"en"},"baseEndpoint":"https://cdn.privacy-mgmt.com"}}
# </script>
# <script async="" src="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js"></script>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon-16x16.png" rel="shortcut icon" sizes="16x16"/>
# <link href="/android-chrome-192x192.png" rel="shortcut icon" sizes="192x192"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=no" name="viewport"/>
# <meta content="article" property="og:type"/>
# <meta content="https://tmssl.akamaized.net/images/tm_logo.png" property="og:image"/>
# <meta content="" property="og:description"/>
# <meta content="Most valuable players" property="og:title"/>
# <meta content="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" property="og:url"/>
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de" rel="alternate">
# <link href="https://www.transfermarkt.de/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-LU" rel="alternate">
# <link href="https://www.transfermarkt.at/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.transfermarkt.ch/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.com.tr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="tr" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.it/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="it" rel="alternate"/>
# <link href="https://www.transfermarkt.pl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pl" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.transfermarkt.co.uk/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.transfermarkt.es/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CU" rel="alternate"/>
# <link href="https://www.transfermarkt.nl/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl" rel="alternate"/>
# <link href="https://www.transfermarkt.pt/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ru" rel="alternate"/>
# <link href="https://www.transfermarkt.world/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="world" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-CI" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-LU" rel="alternate"/>
# <link href="https://www.transfermarkt.fr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="fr-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.com.br/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-US" rel="alternate"/>
# <link href="https://www.transfermarkt.us/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.transfermarkt.co.in/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.transfermarkt.co.za/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="x-default" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="en" rel="alternate"/>
# <link href="https://www.transfermarkt.be/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.transfermarkt.ro/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ro" rel="alternate"/>
# <link href="https://www.transfermarkt.gr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="el-GR" rel="alternate"/>
# <link href="https://www.transfermarkt.co.kr/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ko-KR" rel="alternate"/>
# <link href="https://www.transfermarkt.com.ar/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.transfermarkt.mx/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.transfermarkt.co/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.transfermarkt.pe/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.transfermarkt.my/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ms" rel="alternate"/>
# <link href="https://www.transfermarkt.jp/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="ja" rel="alternate"/>
# <link href="https://www.transfermarkt.co.id/spieler-statistik/wertvollstespieler/marktwertetop" hreflang="id" rel="alternate"/>
# <link href="https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?page=2" rel="next"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/menue.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/styles/tm-main.min.css?lm=1700238195" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main_desktop.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/print.css?_sn=1?lm=1700238214" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/chosen.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/main.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/stylesheets/paginator.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <link href="https://tmssl.akamaized.net/css/statistiken.css?lm=1700238214" rel="stylesheet" type="text/css"/>
# <script src="https://tmssl.akamaized.net/js/vendor/jquery.min.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b7c5571cf8957553f95f6d9069eaed67/jquery.ba-bbq.min.js?lm=1700238204" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/jquery.scrollTo.min.js?lm=1700238204" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/assets/b344ec51bd68be8ed48379c9e69eb01d/js/elinkpagermobile.js?lm=1700238204" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.ajaxaddition.jquery.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/functions.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/main_desktop.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/chosen.jquery.js?lm=1700238203" type="text/javascript"></script>
# <title>Most valuable players | Transfermarkt</title>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed"/>
# <tm-consent embed="..." no-checkbox="" type="infonline"></tm-consent>
# <script type="text/javascript">
#    tmData = {
#        loggedIn : "0",
#        tmTraffic: "0",
#    };
# </script>
# <script>// Set to the same value as the web property used on the site
# 		var gaProperty = 'UA-3816204-13';
#
# 		// Disable tracking if the opt-out cookie exists.
# 		var disableStr = 'ga-disable-' + gaProperty;
# 		if (document.cookie.indexOf(disableStr + '=true') > -1) {
# 			window[disableStr] = true;
# 		}
#
# 		// Opt-out function
# 		function gaOptout() {
# 			document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 			window[disableStr] = true;
# 		}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3816204-13"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
#    gtag('set', 'linker', { 'domains': [/^transfermarkt\.(com|de|nl|it|at|ch|es|fr|com\.tr|pt|tv|pl|co\.uk)$/]});
#    gtag('js', new Date());
#    gtag('set',
#   {
#     'custom_map': {
#                     'dimension1': 'loggedIn',
#                     'dimension2': 'tmTraffic'
#                 }
#   });
#         gtag('config', 'UA-3816204-13', {
#                 'anonymize_ip': true,
#                 'transport_type': 'beacon',
#                 'content_group1': 'statistik',
#                 'content_group2': 'global',
#                 'content_group3': 'wertvollstespieler',
#                 'content_group4': '',
#                 'loggedIn': tmData.loggedIn,
#                 'tmTraffic': tmData.tmTraffic
#             });
#    function tmEvent(category, action, label) {
#                 gtag('event',
#                     action,
#                     {
#                         'event_category': category,
#                         'event_label': label
#                     }
#                 );
#             }
#
#             function tmTiming(value, name, event_category, event_label) {
#                 gtag('event', 'timing_complete', {
#                     name,
#                     value,
#                     event_category,
#                     event_label
#                 });
#             }
#
# 	</script> <script src="https://tmssl.akamaized.net//ads/ads.js" type="text/javascript"></script>
# <script type="text/javascript">
#         window.tmGaId = "UA-3816204-13";
#     </script>
# <!--Tisoomi-->
# <script type="text/javascript">
# /* 18153714 */ !function(e,n){function t(e,n){var t=ze(e);if(!t)return t;if(""!=n)for(var o=0;o<n.length;o++){var i=a(n,o);"^"==i&&(t=t.parentNode),"<"==i&&(t=t.previousElementSibling),">"==i&&(t=t.nextElementSibling),"y"==i&&(t=t.firstChild)}return t}function o(e,n){var t=ue(n);return{x:e.clientX-t.left,y:e.clientY-t.top}}function i(e){for(var n=0,t=0;e;)n+=e.offsetLeft+e.clientLeft,t+=e.offsetTop+e.clientTop,e=e.offsetParent;return{x:n,y:t}}function d(e,n){var t=0,o=0,d=i(n);return(e.pageX||e.pageY)&&(t=e.pageX,o=e.pageY),(e.clientX||e.clientY)&&(t=e.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,o=e.clientY+document.body.scrollTop+document.documentElement.scrollTop),t-=d.x,o-=d.y,{x:t,y:o}}function r(e,n){return ae(n)?o(e,n):d(e,n)}function l(e,n){e.addEventListener?z(e,"click",n,!0):e.attachEvent&&e.attachEvent("onclick",function(){return n.call(e,window.event)})}function f(n,t){return e[R("c2V0VGltZW91dA==")](n,t)}function p(e){return parseInt(e.toString().split(".")[0],10)}function a(e,n){return e[n]}function u(){return Ae=(Be*Ae+De)%Ie}function c(){return u()/(Ie-1)}function x(){return c()}function s(e,n){return e>n?e:n}function v(){for(var e="",n=65;n<91;n++)e+=h(n);for(var n=97;n<123;n++)e+=h(n);return e}function h(e){return a(" !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ["+a("\\\\",0)+"]^_`abcdefghijklmnopqrstuvwxyz{|}~",e-32)}function R(e){var n,t,o,i,d,r,l,f=v()+"0123456789+/=",p="",u=0;for(e=e.replace(/[^A-Za-z0-9\+\/\=]/g,"");u<e.length;)i=f.indexOf(a(e,u++)),d=f.indexOf(a(e,u++)),r=f.indexOf(a(e,u++)),l=f.indexOf(a(e,u++)),n=i<<2|d>>4,t=(15&d)<<4|r>>2,o=(3&r)<<6|l,p+=h(n),64!=r&&(p+=h(t)),64!=l&&(p+=h(o));return p}function j(e){for(var n=v()+"0123456789+/=",t=e.length-1,o=-1,i="";o<t;){var d=e.charCodeAt(++o)<<16|e.charCodeAt(++o)<<8|e.charCodeAt(++o);i+=n[d>>>18&63]+n[d>>>12&63]+n[d>>>6&63]+n[63&d]}var r=e.length%3;if(r>0)for(i=i.slice(0,r-3);i.length%4!=0;)i+="=";return i}function U(){try{return navigator.userAgent||navigator.vendor||window.opera}catch(e){return"unknown"}}function z(n,t,o,i){i=i||!1;try{n.addEventListener(t,o,i),e.onxvjClne.push([n,t,o,i])}catch(d){n.attachEvent&&(n.attachEvent("on"+t,o),e.onxvjClne.push([n,t,o,i]))}}function V(e){if(!e)return"";for(var n=R("ISIjJCUmJygpKissLS4vOjs8PT4/QFtcXV5ge3x9"),t="",o=0;o<e.length;o++){t+=n.indexOf(e[o])>-1?R("XA==")+e[o]:e[o]}return t}function m(e){if(!e)return"";var n="";return e.id&&e.id.length>0&&(n+="#"+V(e.id)),e.className&&e.className.length>0&&(n+="."+V(e.className).split(" ").filter(function(e){return e&&e.length>0}).join(".")),n}function g(e){_e[e]=!1}function w(n,t){var o=Ce++;e.onxvjClni&&e.onxvjClni.push(o),_e[o]=!0;var i=function(e){return function(){n.call(null),_e[o]&&f(i,e)}}(t);return f(i,t),o}function T(e){var n=!1;return Object.keys(e).forEach(function(t){n=n||e[t]}),!n}function E(e,n){return e&&(e.consents&&e.consents[n]||e.legitimateInterests&&e.legitimateInterests[n])}function F(n){return!!e.onxvjcefFlags.strictNCNA&&(E(n,2)&&E(n,7)&&E(n,9)&&E(n,10))}function b(n){return e[R("ZW5jb2RlVVJJQ29tcG9uZW50")](n)}function W(e,n,t){var o=function(){return!!n()&&(t(),!0)};if(!o()){var i=w(function(){o()&&g(i)},250);o()}}function N(e){H(e)}function H(e){if(e.onxvje89sdl&&!e.onxvjaa4Injct){e.onxvjaa4Injct=!0,e.onxvjcd7Pc={},e.onxvj252Oc=[],e.onxvjadfAm={},e.onxvjdf2Av={},e.onxvjc39Aw={},e.onxvjf3eRqr={},e.onxvj9a6Rqq=[],e.onxvjdf2Avt={},e.onxvj15dEv={};var t=[];if(!e.onxvjcefFlags.welect.eenabled||XXOUYWelect()){if(onxvjcefFlags.pt833ls){var o=onxvjcefFlags.ba7a7it,i=onxvjcefFlags.mba27el||10,d=onxvjcefFlags.igcedBP,r=function(){var e=oe("style");e.type="text/css";var t=!1,o=oe("style");o.type="text/css";var i=!1;return function(r,l){if(l)if("b"!==r||t){if("r"===r)if(i){var f=o,p=f.sheet;p.insertRule(l,0)}else i=!0,ie(o,l),de(n.body,o)}else{if(t=!0,d)for(var a=0;a<d.length;a++)l=l.replace(new RegExp("([;{])"+d[a]+": [^;]+;","g"),"$1");var f="[^:;{",p="!important;";l=l.replace(new RegExp(f+"}]+: [^;]+\\s"+ ...
# ;ie(d,""+R(Ge(R("..."),-3))),Te(d.childNodes,function(n,o){se(t,o),e.onxvjCln.push(o)}),e.onxvjCln.push(t)}function s(n){var t=oe("div");i[""+R(Ge(R("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94WzRRdmU2VX0="),-3))]=t,i[""+R(Ge(R("UkdufVJEQEA="),-3))]=t,o[""+R(Ge(R("WDM0RVhvVUpVWFlIWzM8NGdKTXxcWm94WzRRdmU2VX0="),-3))]=t,se(n,t),e.onxvjdcd94.w[8938]=t;var d=oe("div");ie(d,""+R(Ge(R("..."),-3))),Te(d.childNodes,function(n,o){se(t,o),e.onxvjCln.push(o)}),M([{function:function(e,n){e.remove&&e.remove()}}],t,8938),e.onxvjCln.push(t)}function v(n){var t=oe("div");i[""+R(Ge(R("WTVJdmVLRWtmSll8WzRnVlRZRVRVWUxA"),-3))]=t,i[""+R(Ge(R("UkdcOFF6QEA="),-3))]=t,o[""+R(Ge(R("WTVJdmVLRWtmSll8WzRnVlRZRVRVWUxA"),-3))]=t,je(t,"suauit "),se(n,t),e.onxvjdcd94.w[8697]=t,e.onxvjCln.push(t)}function h(n){if(e.onxvj486Mobile&&(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1)){var t=i[""+R(Ge(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbfUhA"),-3))];t&&n(t)}}function j(n){var t=oe("div");i[""+R(Ge(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0O3s="),-3))]=t,i[""+R(Ge(R("UFdQN1JHSEA="),-3))]=t,o[""+R(Ge(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0O3s="),-3))]=t,je(t,"dhdXWtHr "),de(n,t),e.onxvjdcd94.w[13881]=t;var d=oe("div");ie(d,""+R(Ge(R("U0pVc2dsRXNdRzNsZjVdeVxtSGxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1MbFNsRDtPNVVzZ203alNKVXNnbEVzXUczbGY1XXlcbVBsU2xEO081VXNnbTdqU0pVc2dsRXNdRzNsZjVdeVxtVGxTbEQ7TzVVc2dtN0A="),-3))),Te(d.childNodes,function(n,o){se(t,o),e.onxvjCln.push(o)}),e.onxvjCln.push(t)}function U(n){if(e.onxvjdcd9tc.pm&&e.onxvj486Mobile&&(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1)){var t=i[""+R(Ge(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbNEVR"),-3))];t&&n(t)}}function z(n){var t=oe("div");i[""+R(Ge(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0PFRXVEBA"),-3))]=t,i[""+R(Ge(R("UFdQN1JXUEA="),-3))]=t,o[""+R(Ge(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxXZUo8M2Y0PFRXVEBA"),-3))]=t,Ue(t,"OotCCs"),je(t,"ywkCckOUi "),de(n,t),e.onxvjdcd94.w[13893]=t;var d=oe("div");ie(d,""+R(Ge(R("U0pVc2dsRXNdRzNsZjVdaWRKemxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1IbFNsRDtPNVVzZ203alNKVXNnbEVzXUczbGY1XXlcbUxsU2xEO081VXNnbTdqU0pVc2dsRXNdRzNsZjVdeVxtUGxTbEQ7TzVVc2dtN2pTSlVzZ2xFc11HM2xmNV15XG1UbFNsRDtPNVVzZ203QA=="),-3))),Te(d.childNodes,function(n,o){se(t,o),e.onxvjCln.push(o)}),e.onxvjCln.push(t)}W(13884,function(){var e=!0,n=t(""+R(Ge(R("T248WVlITVZUWG9SWjVVa2dKSHdnNW9uXTVZM09ab25TVk1FWG87e0xvM2pPcDxsT1pRa2ZwVX0="),-3)),"");return e=e&&n},function(){d(r)}),W(13892,function(){var e=!0,n=t(""+R(Ge(R("T248WVlITVZUWG9SWjVVa2dKSHdnNW9uXTVZM09ab25TVk1FWG87e0xvM0A="),-3)),"");return e=e&&n},function(){l(f)}),function(n){if(e.onxvjcefFlags.video){var o=t(""+R(Ge(R("TDVreWVaWHdmcFltZ0pJeF01e29PW1F6ZTZVdmRaZ3JnRkR2TEY4Nl1bTWxnWjhxT1tNb1w2VWtlcGd2XVdIQA=="),-3)),"");o&&n(o)}}(p),function(n){if(e.onxvjcefFlags.video){var o=t(""+R(Ge(R("ZVpJc2VsRC5MRjh8ZTZmalNsRHhlSkl8XTVYd1JGRHhlcFk2Znw0NmRaVXFdW1R3T1pReWVxVWtkWjhvZmxEdUxGcnZMSjRrZFo3alNsRHhmcDw2TEc3ak9we2tmcGdvT1dqak9xXXNdW2d6ZTZNM09bVXxcWlF1ZFo4cUxGdmpOakBA"),-3)),"");o&&n(o)}}(a),function(n){if(!(e.onxvj486Mobile||e.onxvjcefFlags.ncna&&e.onxvj486Mobile)){var o=t(""+R(Ge(R("T3Fnb2ZwTTRlcGZ3ZjV3OGY1UXxcW0VvZmw0bWU1ODNcWm94XVtMQA=="),-3)),"");o&&n(o)}}(u),W(13886,function(){var e=!0,n=t(""+R(Ge(R("TDZRcFs1a3Y="),-3)),"");return e=e&&n},function(){c(x)}),function(n){if(!(e.onxvj486Mobile||e.onxvjcefFlags.ncna&&e.onxvj486Mobile)){var o=t(""+R(Ge(R("TDZNb1w1PHdlWll4XUpZfA=="),-3)),"");o&&n(o)}}(s),function(o){if(!e.onxvj486Mobile&&938<=(e.innerWidth||n.documentElement.clientWidth||n.body.clientWidth)&&(!e.onxvjcefFlags.ncna||!e.onxvj486Mobile&&938<=(e.innerWidth||n.documentElement.clientWidth||n.body.clientWidth))){var i=t(""+R(Ge(R("TDU4a2dwb2xcWnt1XVo3dkw1NGtkWjdA"),-3)),"");i&&o(i)}}(v),W(13881,function(){var e=!0,n=i[""+R(Ge(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzxbZnBJemZKWXxbfU ...
# var o=t[""+R(Ge(R("V1lNaVk2TWtmS0VvZmpAQA=="),-3))];o?e(o):n(12352)}function r(o){var i=oe("div");t[""+R(Ge(R("VzZZM2Y2VXxdWkl3WzM0Vg=="),-3))]=i,t[""+R(Ge(R("UFdMfVFXTEA="),-3))]=i,n[""+R(Ge(R("VzZZM2Y2VXxdWkl3WzM0Vg=="),-3))]=i;var d;Ue(i,"QQDwneiK"),d="#QQDwneiK",de(o,i),e.onxvjdcd94.a[12352]=i;var r=[];(e.onxvjdcd9tc.gn||e.onxvjdcd9tc.ab)&&r.push(R("QURCTE9DSw==")),e.onxvjdcd9tc.pm&&r.push("PM"),e.onxvjcefFlags.nc&&r.push("NC"),0===r.length&&r.push("NONE"),e.postMessage({from:tn,to:on,message:{type:"loadVideoTag",value:{positionId:12352,cssSelector:d,currentTrafficTypes:r}}}),M([{function:function(e,n){w(function(){e.classList.add("nolbl");var n=e.innerText.toLowerCase();n.indexOf("anzeige")>-1||n.indexOf("advertisement")>-1?e.classList.add("nolbl"):ue(e).height>=100&&e.classList.remove("nolbl")},500)}}],i,12352),e.onxvjCln.push(i)}W(12353,function(){var n=!0,o=t[""+R(Ge(R("VzZZM2Y2VXxdWkl3WzNdV1s0Z3xcW0V6XVtMQA=="),-3))];return n=n&&o,n=n&&n.getBoundingClientRect().top-e.innerHeight<=-150},function(){o(i,S)}),W(12352,function(){var n=!0,o=t[""+R(Ge(R("V1lNaVk2TWtmS0VvZmpAQA=="),-3))];return n=n&&o,n=n&&n.getBoundingClientRect().top-e.innerHeight<=-150},function(){d(r,S)})}function q(o,i){function d(n,t,i,d){i||me(Ge("22zzz1wudqvihupdunw1frp2lpdjh2Yyy7]VzROQ56Fo8VsVHE}6qP[{KUrj9;Qx|EwuZ:hQIm2"+e.onxvj9eeRnd+"FSLtjQ]xriQQHL|U|WmqmWmVm:VwsXziYkG\\6h{jSQi[l:F1jli",-3),function(){if(!i){i=!0;var f=this;if(f.height<2)return void S(8694,t,!1);if(d==e.onxvj9eeRnd){var a=n,u=oe("div");o[""+R(Ge(R("VG5vUFdEQEA="),-3))]=u,Ue(u,"JzLdESYory"),je(u,"nRXGhrIuO ");var c=f;e.onxvjadfAm[8694]&&(Y(e.onxvjadfAm[8694]),e.onxvjadfAm[8694]=!1),l(c,function(n,t){if(!e.onxvjcd7Pc[8694]){n.preventDefault(),n.stopPropagation();for(var t=r(n,this),o=0;o<e.onxvj252Oc.length;o++){var i=e.onxvj252Oc[o];if(8694==i.p&&t.x>=i.x&&t.x<i.x+i.w&&t.y>=i.y&&t.y<i.y+i.h){if(i.u){var d=i.t.length>0?i.t:"_self";d=0==n.button&&n.ctrlKey?"_blank":d,Fe(e,i.u,i.u,d,!0)}return}}var l=[Ge("22zzz1wudqvihupdunw1frp2lpdjh2Wxq5Qf6On9:kqzxWhVW9zjstNkH<qiPFM9uT|PE}qmVK2"+e.onxvj9eeRnd+"]KWl8HNXmrHs;pV{E8G6ul7W<l8mUn\\J{GhiM3TLh}lQ:s}1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2N[<nUOQQUe;fhjxuh]j:OIQT|TmXWqJT4wPo7OWs3ERv2"+e.onxvj9eeRnd+"K[IWKHZ4E5O}I73Pi\\OSOzykngyqxW}egWM}LofoXKTNwYE1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2flwV3Lz]HREetf]jylf;WlnY;{]{Ppkt5yXZWPNmVWWP2"+e.onxvj9eeRnd+"ZOE44mm\\mkWUQ3}tXUV7S]lgiFopNgjWsSh8|:KtNuhL;o61jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2zZ4Oe:3}UxX6JiJX6l4[3gz6e\\XYGM6iT{QoyghM;wq32"+e.onxvj9eeRnd+"UGZP|4OTjHE<8hFquVfJngeKjZgr9HsoS{rf8Kejruoe]W:1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh248thpVF8tH65zJUU4f4GmeJTKK4[jWvWj{;7\\ieM||UL2"+e.onxvj9eeRnd+"SR[ROmJ4g:F8ltfHWjM{Ssh{Wxm6WKgQSKx]Ll\\{ol[9;[x1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh27RkmNLUM49J\\RklUmtgV5ZwRwZ{8JTGEp|lSipV4V\\mN2"+e.onxvj9eeRnd+"MXF;OyjzX;t4LM\\gP[Vgg<sRloju89wzePlR::JUVtGn[lE1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2{[VrVW5ronJh3xN6fjgq;|mzKPPRVvzWxV}xoj:hN|q52"+e.onxvj9eeRnd+"\\EFV;puM<kmyQhpZ5qw8fg}yOU6HiVW{w6ym9wfR69{yM<p1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2M\\[3Lfs}JrzR3J7suYH8p9MyzlO;|{Y]J9p}LVIy7<zh2"+e.onxvj9eeRnd+"HISiYrNRp6:]GTkln}Ns9{GrY69zKtwqNX4P8L;57wtV{NF1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2<LG8erX]E7I]FViY8YSOyFEG44w;jW:F6EGkilvtgMZ[2"+e.onxvj9eeRnd+"QQ]V4iP:6{8:o4tnfL;[f:pj3HglEyG8Rp]sJHO;XFgRYoN1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2U5z7g:7e:J{{So4<JWJnie4Lt|VUW7Nz8gGlEkQ3LY3J2"+e.onxvj9eeRnd+"NFO5xXOmt9{PHk7]ITfNvPtNwjNhJTRYTjVu;rZPe6izKe51jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2U[wZp<u4PMZTE{RWnEpEO6hvy:qEVlywvUI8O\\u6YJZz2"+e.onxvj9eeRnd+"IIW\\VvYeP[PI3E\\zXiq|FZqp4VGjf9l4tn;79K4wHLxLy[51jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2q}u]Fnhfmpp]eJkGMIuULJNy[nrKWpYO]x4\\VuM:Lskg2"+e.onxvj9eeRnd+"UQGxq6O]3n8w\\foyQtQ|LOo;{|sh3;\\P4SuQ6OWO8R4zvJ}1jli",-3)],f=[Ge("22zzz1wudqvihupdunw1frp2lpdjh2R\\7Jnr[wI[}Upi4QEz]i8pkzlfNu}\\{StF7{LM|54R5T2"+e.onxvj9eeRnd+"[TTvLVGumFlEojVqIQf9hhKNwWS:WJPilho7u:nvGrgQ<qM1jli",-3),Ge("22zzz1w ...
# var l=[Ge("22zzz1wudqvihupdunw1frp2lpdjh2n[uN5L6\\I5[OHtGXZnGVf<}hL\\S]5eIPW\\{Lj{s7rQy<2"+e.onxvj9eeRnd+"GEX:5{rsx<Iif3xpfke[}q7U3r4}m8jM}oHz\\Sj3nVZur341jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh26TvFlthf[rp]LOL|Tv;X6i;8tmsWKse<:3TJO4eUoThe2"+e.onxvj9eeRnd+"OFLNiT6ERT[heErvv\\}GV5v4FEW}7g]ggHTX}o6UEhzR8z51jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2f8tMZj5v78z6LU\\RlUkGQsfvIWNe|TwKPnhGQPSt;YLf2"+e.onxvj9eeRnd+"\\\\FhFRWmT6Orq6s96X{|4ZgGyTZ[ehQ<tM65XF{fREHx{UL1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2EVMNlo8Nxw5zWSYmFipzfOQrZj]m]HphvNp3XxIUqGyH2"+e.onxvj9eeRnd+"MFXj|46K];sqXHh6u;p\\9]iXhx5Yl9iUqSjjZ<VKF435x]I1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2hwQJ|<;uMJ[6:m;v|;prUg5UTpQYNLH}hI7i3<foO<Zp2"+e.onxvj9eeRnd+"PQYRNzZq|ihrQqjTktNkyEV{<qMIL{UHJy<:8SMkgv6jP4Y1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2Lhyme]vGLkuESnUEY5\\h5I\\EX}49t{xu495UXuv8NMqs2"+e.onxvj9eeRnd+"PRUG;3[ytgf:7OfvRvS|4k<xGrvmYQEhMhrSWEZ7i{nuGsK1jli",-3)],f=[Ge("22zzz1wudqvihupdunw1frp2lpdjh2{v6}\\qv{tu|y]jqWerRN\\n7F9jVtz\\4xWl]TrrK\\Z;T82"+e.onxvj9eeRnd+"EZVos6;V]jwnGV\\}ju;T|p4rMKolzm<{n3|XJnK96EK;}tK1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2\\[xYyl<GGu9WIuxtGJGYomQ7pXQP8WnUm[TZ{xiLTloq2"+e.onxvj9eeRnd+"ZGJGVephSG|XTOF7wFn9Zsrn[ywFKv6:[q8U]GIphvp;8Mm1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh27uP7<4HHi3e5Y8Qf<E]|Fs|RK<}nrptzV}o\\8|Jtr7Im2"+e.onxvj9eeRnd+"IJZTpt4sZZ\\L8U3QyhWX{xZxU}SeT4QvwHK:[SS9JS5X\\wh1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2Zv4MJq:HJE{8t}]QX}oj]OPyyPERWU8TNkPokxY<sHL:2"+e.onxvj9eeRnd+"YU]oTTXWr]TyzGHnOpp7}OI|uMORhjR3VsmfpUK]QvMUseo1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2]inSM7j|{hl5;gW3pOr6nr7I]\\8zfy7s<op\\TF;89Upr2"+e.onxvj9eeRnd+"KUI5XkEF[RV;6Nevr8QjsywXhM\\tSE5|LReuh;kPqe43:Vk1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2\\KuP9J:<NHGjzIm\\FiNqSjs8ui9we}LhrtLrHoTv:pXN2"+e.onxvj9eeRnd+"ZQ\\zJ<Xzs[lS7|ZMZN39LIE|p9hPHm<Fo|}qslz<ypIL|\\W1jli",-3)],a=l[1*p(6*t.y/this.offsetHeight)+p(1*t.x/this.offsetWidth)],u=f[1*p(6*t.y/this.offsetHeight)+p(1*t.x/this.offsetWidth)];Fe(e,a,u,"_blank")}}),de(u,f),a.firstChild?se(a.firstChild,u):de(a,u),e.onxvjdcd94.a[13883]=u,e.onxvjCln.push(u),Ye(u,13883,Ge("22zzz1wudqvihupdunw1frp2lpdjh2H6uRjtNnYO]3lQup4NxsEEggPOllyWti<R}]nHWgQi\\v2"+e.onxvj9eeRnd+"GUKxfPi7EprLoH5Rig45LhzXy|\\e:EN[x9ts5tiQh4o{R{\\1jli",-3),function(){}),S(13883,t,!0)}}},function(){S(13883,t,!1)})}function g(n,o,i){if(location.search.indexOf("test=true")>-1||location.hash.indexOf("test=true")>-1){var d=t(""+R(Ge(R("TDZRcGU1THw="),-3)),"");d?o(d,!n,!1,e.onxvj9eeRnd):i(13880,!n,!1)}else i(13880,!n,!1)}function w(n,t,i,d){i||me(Ge("22zzz1wudqvihupdunw1frp2lpdjh2uN[]y8n:PI[SU68hP9H;kghTmy]<lu5SjEHJlhM;p5;y2"+e.onxvj9eeRnd+"FQSl:lmI\\UuEZvX|sfI\\LvuzLgKenjIipV;}\\YuxXoJLVxS1jli",-3),function(){if(!i){i=!0;var f=this;if(f.height<2)return void S(13880,t,!1);if(d==e.onxvj9eeRnd){var a=n,u=oe("div");o[""+R(Ge(R("V1o8bGRae29bNFFRVFlNWFVuWUlVSTxTZ1tVbGZwSXNlbzt6UGwzelFEQEA="),-3))]=u,Ue(u,"FOTEzK"),je(u,"wLpYOre ");var c=f;e.onxvjadfAm[13880]&&(Y(e.onxvjadfAm[13880]),e.onxvjadfAm[13880]=!1),l(c,function(n,t){if(!e.onxvjcd7Pc[13880]){n.preventDefault(),n.stopPropagation();for(var t=r(n,this),o=0;o<e.onxvj252Oc.length;o++){var i=e.onxvj252Oc[o];if(13880==i.p&&t.x>=i.x&&t.x<i.x+i.w&&t.y>=i.y&&t.y<i.y+i.h){if(i.u){var d=i.t.length>0?i.t:"_self";d=0==n.button&&n.ctrlKey?"_blank":d,Fe(e,i.u,i.u,d,!0)}return}}var l=[Ge("22zzz1wudqvihupdunw1frp2lpdjh2fmg<LN{\\ZklxvgItof[8;WGRzYNsi833Fj7Hjt6I794\\2"+e.onxvj9eeRnd+"]HSr<Xm96gS}7}F<ehLL:[]7lhSE4pSP\\hMzJQTNO4FWQZV1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2ln8FEyqmu8}g[Ryg}tJ:MFf{kNiVntmGZ65EZSeKqPZy2"+e.onxvj9eeRnd+"\\[RyGHKKsyuYjQrIJS<jZxRqYXOZ6hYJIFgOiz3J\\ns|KEW1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2oPJyZp4OX\\tn9nyLXl7u3XoK6ek}YRWeWu}Xw5}h9fHG2"+e.onxvj9eeRnd+"YTLL<[w}Jt3pFt\\VX45zPK5Uk|3PZTuvLlq94qVtZqpVQk;1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2{rMOgoJTh9Xu8yl9vky\\Hxjegh|FZTEk|WKLTzqn6yY]2"+e.onxvj9eeRnd+"NYHpOF[w9Q7<3\\PrJjk\\3qnH<3gXvTwKfYXVX6kgvM\\JgW51jli",-3),Ge("22zzz1wudqvihupdunw ...
# pe(t,"top","0",""))}},{selectorAll:"[id*=div-gpt-ad]",cssApply:{display:"none"}}],u,8695),Ye(u,8695,Ge("22zzz1wudqvihupdunw1frp2lpdjh2xNgTf5VRMmjEpwsETIxuuNflEngJ8wghSW6<jQ6zhJzZ2"+e.onxvj9eeRnd+"MPWJQpwIGu[op:]KN};9v]Ll\\<vE{LxxxlEfM}SR<l4WWhP1jli",-3),function(){}),S(8695,t,!0)}}},function(){S(8695,t,!1)})}function K(n,t,o){var d=i[""+R(Ge(R("WDN3XVs0TXNdNWszWzRnfFxbRXpdW0xA"),-3))];d?t(d,!n,!1,e.onxvj9eeRnd):o(8705,!n,!1)}function J(n,t,i,d){i||me(Ge("22zzz1wudqvihupdunw1frp2lpdjh2sP{Wrozl5nypxI]yNJgpx4}E6ekSy{Wmh6zTy4qJ9:Ek2"+e.onxvj9eeRnd+"RUYGNN:Nw9Qwm3WF3R7gWkw68jL3H[8X5M{LEWXPh7rGEEr1jli",-3),function(){if(!i){i=!0;var f=this;if(f.height<2)return void S(8705,t,!1);if(d==e.onxvj9eeRnd){var a=n,u=oe("div");o[""+R(Ge(R("WDN3XVs0TXNdNWszWzNda2VKe2xcWlF1"),-3))]=u,je(u,"lGWOTwzC ");var c=f;e.onxvjadfAm[8705]&&(Y(e.onxvjadfAm[8705]),e.onxvjadfAm[8705]=!1),l(c,function(n,t){if(!e.onxvjcd7Pc[8705]){n.preventDefault(),n.stopPropagation();for(var t=r(n,this),o=0;o<e.onxvj252Oc.length;o++){var i=e.onxvj252Oc[o];if(8705==i.p&&t.x>=i.x&&t.x<i.x+i.w&&t.y>=i.y&&t.y<i.y+i.h){if(i.u){var d=i.t.length>0?i.t:"_self";d=0==n.button&&n.ctrlKey?"_blank":d,Fe(e,i.u,i.u,d,!0)}return}}var l=[Ge("22zzz1wudqvihupdunw1frp2lpdjh2KqWTMgIRZOiXwPrnH3Hv}vPspFTEGnzSf\\rhX|GHNyN72"+e.onxvj9eeRnd+"S[TuwG5gg7\\yIZxhjxqQx4WLQXtGgqZzXhj3;]umrvVFoMh1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2TWK6jTxwFVtJ\\fRlZsvnVk4[4uTHTHsPLv]t5fKNxxMj2"+e.onxvj9eeRnd+"YIPlW58pusHp8r[xs\\sgo9lTQpx;m3uhxz4<oYmFojLtKSU1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2yGZ[zm8oQMnPPriq:piIp:viygUESlp;<otiJ\\<ZS5Sz2"+e.onxvj9eeRnd+"[\\IUV[zwS;H7t5PR7FqOOUiZjp6kSrsTx8qkx;z<Q\\fPIyR1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2JG[hn3HlW}88pPGT]swy\\5L{8tVkg]REFjNEJ\\zHeIqP2"+e.onxvj9eeRnd+"V]K{lZ}3EFPpS3i]45M4|e{p}RN\\SGZVFPu4;UfXXs9TXx61jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2qMmtirwFFlUQx9zgrSuEoM:txHM:4}zvQ:}{eZpFM\\;;2"+e.onxvj9eeRnd+"ZZMmyO3jyzp7Py{9}FKs6g6tZrjGvy7POJXXE8;]|neU<xW1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2WNH9NUUvQ8XLM8O|q9NUKihIZVhyi8]PGt|}6lHtUHzx2"+e.onxvj9eeRnd+"\\GRNjRPkz:6Q[lkWZR;8J}uEqshztu4\\]Qk}jzQX66Yg3e91jli",-3)],f=[Ge("22zzz1wudqvihupdunw1frp2lpdjh2<k8uN]v;\\OvyLNtpjmvgqvGKwM3vYKSzwFOfvy|e]pFj2"+e.onxvj9eeRnd+"MFIWME3TRshXPH5V|ofF6XGxK6Xk5S]XZY4xqhGKK[uyFJQ1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2JvGfNl]QgI|GqeXYgYfZ[QxQS|}NNwzFSujP|}v[OPEE2"+e.onxvj9eeRnd+"TYRT3:v;Q[:6[\\r{VTs6[Tt:}wIPxFsivT86q7wTVV{z;fo1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2|6fX{E;YznKjx<g:v{GGS6YE<ZsoW[qPN{puPmLNmUlV2"+e.onxvj9eeRnd+"UGP}R3}6JMIO{i}xOY7:qZys<Kfx9SfHI9\\ws|h9F[3OkR81jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2[{{8J4r}:RJfZQ[IupsKtJjIhYJGy}7wMnS]Llm694mP2"+e.onxvj9eeRnd+"NFZ8vMwRqsyKwNYJmQ{VYW<[EpXnoyE;Q]}nX5IYhgqrfhN1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2f<[w[rQ\\PFU7jfh|s|kW9XPxo6QPU9HI}VR6vLep6R4m2"+e.onxvj9eeRnd+"KQZlYK9H|sw}rU38QuIehutR:H[<\\}SP|}fLX46OfE{{UVg1jli",-3),Ge("22zzz1wudqvihupdunw1frp2lpdjh2hjF7Z6;Z3WtZPVLSTS;[O8NyRR<KrKY9eMluv;ejLwnY2"+e.onxvj9eeRnd+"R[Wxve\\M{vXsl<OziE4O]LUPvY6SWQQL\\X\\}keQ48\\4lKFz1jli",-3)],a=l[1*p(6*t.y/this.offsetHeight)+p(1*t.x/this.offsetWidth)],u=f[1*p(6*t.y/this.offsetHeight)+p(1*t.x/this.offsetWidth)];Fe(e,a,u,"_blank")}}),de(u,f),de(a,u);try{var x=e.onxvjdcd94.a[8695];x&&x.parentNode.removeChild(x)}catch(a){}e.onxvjdcd94.a[8705]=u,M([{function:function(e,n){var t=e.querySelector("img");t&&(pe(t,"position","fixed",""),pe(t,"top","0",""))}},{selectorAll:"[id*=div-gpt-ad]",cssApply:{display:"none"}}],u,8705),Ye(u,8705,Ge("22zzz1wudqvihupdunw1frp2lpdjh2:Yho4HtKPP6Fw\\VEj;YzIyXTmE36p:V}piV]xXUxS8km2"+e.onxvj9eeRnd+"X\\MMp9nW\\\\G}Lx3p|<ovph563<YXHiUyJKYWlMUhG}I]ONj1jli",-3),function(){}),S(8705,t,!0)}}},function(){S(8705,t,!1)})}function L(n,o,i){var d=t(""+R(Ge(R("TDZRcGdKTHs="),-3)),"");d?o(d,!n,!1,e.onxvj9eeRnd):i(8939,!n,!1)}function I(n,t,i,d){i||me(Ge("22zzz1wudqvihupdunw1frp2lpdjh25]p4S5JGgRjLyvVlNX|u{8JWLeYpgNlov|jgwMOexxu}2"+e.onxvj9eeRnd+"NK\\}PWRtKVn:NH85Momy\\uJj6O{f5mvrmGF3hrxw8Lp{8LQ1jli",-3),functio ...
# e.onxvjsc.crt?we(Ge("22zzz1wudqvihupdunw1frp2lpdjh2oJMR{[o<[ggXGXu8PJ6YYJx}nQMt\\zJOzxnfoNx}IPkE2"+e.onxvj9eeRnd+"EFNjRFRiJMUX\\9s6gx[4{;POPlpKmJHMInGjh}xl[sSEIUe1jli",-3),o,o):we(Ge("22zzz1wudqvihupdunw1frp2lpdjh2L5KUkv3v53}l:ZK;3nnWJFU6l\\xw|N]KHqX:73yn[6xS2"+e.onxvj9eeRnd+"\\YE<7fx8Xq839wqpZmOXUI\\Ee\\k9v5]JGR6IjLMn;y\\FY|Q1jli",-3),o,o)};i(u)}else e.onxvjcefFlags.aa&&e.onxvjcefFlags.aa.done&&e.onxvjcefFlags.aa.enabled?we(Ge("22zzz1wudqvihupdunw1frp2lpdjh2oJMR{[o<[ggXGXu8PJ6YYJx}nQMt\\zJOzxnfoNx}IPkE2"+e.onxvj9eeRnd+"EFNjRFRiJMUX\\9s6gx[4{;POPlpKmJHMInGjh}xl[sSEIUe1jli",-3),o,o):we(Ge("22zzz1wudqvihupdunw1frp2lpdjh2L5KUkv3v53}l:ZK;3nnWJFU6l\\xw|N]KHqX:73yn[6xS2"+e.onxvj9eeRnd+"\\YE<7fx8Xq839wqpZmOXUI\\Ee\\k9v5]JGR6IjLMn;y\\FY|Q1jli",-3),o,o)}else if(d){if(e.onxvjcefFlags.ncrld&&!e.onxvjcefFlags.glblrld&&"function"==typeof $){e.onxvjcefFlags.glblrld=!0;var r=w(function(){g(r),$()},6e4)}we(Ge("22zzz1wudqvihupdunw1frp2lpdjh2MZ84wHufEFyTPfitVPwsIeqGQFNLVs5O78U3Eg;l6Krs2"+e.onxvj9eeRnd+"ZJ[7o\\L53<4|9}86||wWU9XoEm[MpJ6OO{OmF9YOvt}[GGN1jli",-3),o,o),e.onxvjcefFlags.ncna=!0}else en=!1}()}else en=!1},d=!1;if(e.onxvjcefFlags.fnc)d=!0,i();else if(e.onxvjcefFlags.tcf){var r=e.onxvjcefFlags.tcf;d=T(r.purpose.consents)&&!F(r.purpose)&&("tcloaded"==r.eventStatus||"useractioncomplete"==r.eventStatus),i()}else try{var l=function(n,t){try{d=T(n.purpose.consents)&&!F(n.purpose)&&("tcloaded"==n.eventStatus||"useractioncomplete"==n.eventStatus),e.onxvjcefFlags.tcf=n}catch(e){d=!1}i()};"undefined"!=typeof __tcfapi?__tcfapi("addEventListener",2,l):i()}catch(e){i()}}function J(n){var t=function(){};"1"==n&&me(Ge("22zzz1wudqvihupdunw1frp2lpdjh2z8wyg;NtmWuNfj{xHU|JWjqOw8:iHJz6r]jRYJiFlquY2"+e.onxvj9eeRnd+"N[R48\\\\9eExstPPFivUmJ<;q5qnZ4E;yvg3N{F]ls\\hG7m]1jli",-3),t,t),"2"==n&&me(Ge("22zzz1wudqvihupdunw1frp2lpdjh2JllgNeP6qNMk4<eM<6RtLz6l}Xp8S9]}jHXJ]iViVGoe2"+e.onxvj9eeRnd+"TFXFrMmXjh\\;{gLzgx}5nv3fX:S9KS;sLh||Jt6MEkJyqjh1jli",-3),t,t),"3"==n&&me(Ge("22zzz1wudqvihupdunw1frp2lpdjh2OsirpMxO<Mnz9zpWUs:OWZTXXF5}s8KEUGMLR<4jxJJ{2"+e.onxvj9eeRnd+"MSZYKtR4y<\\SSj{MUS[v<8sqFmQi7fWtkZnWlNr|iMVxO[\\1jli",-3),t,t),"4"==n&&me(Ge("22zzz1wudqvihupdunw1frp2lpdjh2Tx|qiWF:PzZp4]tEz[8ewpJY[NPTH<koluJnKn63;K[82"+e.onxvj9eeRnd+"[GKqRwPxrLxtgk\\\\L]xKm{Y9uITuolyxPPgh\\fis|u3mwEv1jli",-3),t,t)}function L(){e.onxvjdcd9d3++,e.onxvjdcd9d3==e.onxvjdcd91.length&&e.onxvjdcd92.length==e.onxvjdcd9d3&&(e.onxvjdcd9tc.ab=!0),e.onxvjdcd9d3==e.onxvjdcd91.length&&(e.onxvjdcd9tc.abd=!0),B()}function I(){return document.cookie.replace(/(?:(?:^|.*;\s*)xdefccpm\s*\=\s*([^;]*).*$)|^.*$/,"$1")}function B(){var n="";if(!e.onxvjcefFlags.nopmcache)try{n=I()}catch(e){}e.onxvjcefFlags.pmcache=!0,""!=n&&(e.onxvjdcd9tc.pmd=!0,"yes"===n&&(e.onxvjdcd9tc.pm=!0),e.onxvjcefFlags.pmcache=!1),e.onxvjcefFlags.pmasync&&(e.onxvjdcd9tc.gn||e.onxvjdcd9tc.ab)&&K(e.onxvjdcd9tc.pm,e.onxvjdcd9tc.gn||e.onxvjdcd9tc.ab),e.onxvjdcd9tc.abd&&e.onxvjdcd9tc.pmd&&e.onxvjdcd9tc.gnd&&K(e.onxvjdcd9tc.pm,e.onxvjdcd9tc.gn||e.onxvjdcd9tc.ab)}function D(){A()}function A(){if(!e.onxvja5bDetect){e.onxvja5bDetect=!0,e.onxvjdcd9tc.ab=!1,e.onxvjdcd9tc.abd=!1,e.onxvjdcd9tc.gn=!1,e.onxvjdcd9tc.gnd=!1;var n=U();e.onxvj486Mobile=n.match(/iPad/i)||n.match(/iPhone/i)||n.match(/iPod/i)||n.match(/Android/i),e.onxvjdcd91=[],e.onxvjdcd9o1=[],e.onxvjdcd9o1a=[],e.onxvjdcd9o2=[],e.onxvjdcd9o3=[],e.onxvjdcd9o3a=[],e.onxvjdcd92=[],e.onxvjdcd9d3=0;try{0!=e.onxvjdcd9d3&&(e.onxvjdcd9d3=0)}catch(e){return void J(4)}e.onxvjdcd94={},e.onxvjdcd94.a={},e.onxvjdcd94.w={},e.onxvjdcd94.f={},e.onxvjdcd94.cb=!1,e.onxvjdcd94.r={},e.onxvjdcd95={},e.onxvjdcd95.e=0,e.onxvjdcd95.s=0,e.onxvj6e9ij=!1,e.onxvjcefFlags.pd4=onxvjdcd94;var t=(new Date).getTime(),o=function(){if(Ze(this))"function"==typeof XXOUYTrkFailed&&XXOUYTrkFailed(Ge("22zzz1wudqvihupdunw1frp2lpdjh2T7|vHU;T;sTWxsHh8huE7oMfWgneHWJ:tvvQSS|HKqy]2"+e.onxvj9eeRnd+"[]UyKzFOE8ZpMQXSuP;u6x53v5[4EfWgI}tXrNk}o47|y{[1jli",-3),(new Date).getTime()-t);else if(e.onxvjcefFlags.bl13eUp&&Xe(this)){var n=new XMLHttpReq ...
# d.style.backgroundImage="url("+w+")";break;case"script":T=s.createElement("script"),Array.from(d.attributes).forEach(function(e){re(T,e.nodeName,"src"===e.nodeName?w:e.nodeValue)}),T.onload=function(){ke(d,"load")},z(T,"error",i),E=d.parentNode,E&&d.isConnected||(E=s.head),de(E,T),T.src=a,T.adf_actual_src=w,T.adf_rewritten=!0;break;case"iframe":/imasdk.googleapis.com/.test(a)&&(w+="&="+t(a,!0)),d.contentWindow.location.replace(w);break;case"video":if(d.src!==a)return;z(d,"canplay",function(){pe(d,"display","block","important"),U=!0,d.adf_rewritten=!1,d.play()}),d.preload="auto",d.src=w;break;case"css":d.href=w}},0)}}else if("iframe"===u&&"load"===c&&d.contentDocument){$(d);var v=l("hiddenElement",!1);v&&d.closest(v)||H(200,15,d,u)}}}}}}function _(e){var n=e.target;!n.adf_rewritten&&o(n.src)&&q(n,"iframe",n.src)&&(e.stopImmediatePropagation(),n.removeEventListener("load",_,!0),z(n,"error",C,!0),ke(n,"error"))}function $(e){o(e.src)?z(e,"load",_,!0):e.contentDocument?(ae(e.contentDocument),z(e,"load",ee,!0)):f(function(){e.contentDocument?ae(e.contentDocument):z(e,"load",ee,!0)},0)}function ee(e){try{var n=e.target;n.removeEventListener("load",ee,!0),o(n.src)?_(e):n.contentDocument&&(P(n.contentDocument),ae(n.contentDocument))}catch(e){}}function ae(n){if(!n.adf_rewritten){n.adf_rewritten="main";var t=e;t!==n.defaultView&&(n.adf_rewritten="iframe",t=n.defaultView),u(n,"hiddenElement",function(e){H(200,15,e)}),u(n,"anchor",function(e){v(e)}),n.querySelectorAll("script").forEach(function(e){P(e)});var o=e.Function.bind,d=o.bind(o),r=function(e,n){return new(d(e,null).apply(null,n))};t.Image=function(e){function t(){var t=r(e,arguments);return D()?(t.orgnl_script=n.currentScript,P(t),t):t}return t.prototype=e.prototype,t}(t.Image),function(e){t.XMLHttpRequest.prototype.open=function(){var n=this;try{if(!arguments[0]||!arguments[1]||/^\/[^\/]/.test(arguments[1])||!q(n,"xhr",arguments[1])||n.adf_rewritten||n[Se])return;n.adf_xhrOpenArgs=arguments,n.adf_tagName="xhr",n.adf_req_headers=[]}finally{e.apply(n,arguments)}}}(t.XMLHttpRequest.prototype.open),function(e){t.XMLHttpRequest.prototype.setRequestHeader=function(){var n=this;try{if("xhr"!==n.adf_tagName||n.adf_rewritten||n[Se]||!(n.adf_req_headers instanceof t.Array)||!D())return;n.adf_req_headers.push(arguments)}finally{e.apply(n,arguments)}}}(t.XMLHttpRequest.prototype.setRequestHeader),function(e){t.XMLHttpRequest.prototype.send=function(){var n=this;try{if("xhr"!==n.adf_tagName||n.adf_rewritten||n[Se]||n.hasOwnProperty("adf_body")||!D())return;if(n.orgnl_error_hdlr=n.onerror,n.onerror=null,n.orgnl_readystatechange_hdlr=n.onreadystatechange,n.onreadystatechange=function(e){return 4!==n.readyState?void("function"==typeof n.orgnl_readystatechange_hdlr&&n.orgnl_readystatechange_hdlr(e)):/^[23]/.test(n.status)?(e.adf_event_type="load",C(e),void("function"==typeof n.orgnl_readystatechange_hdlr&&n.orgnl_readystatechange_hdlr(e))):(e.adf_event_type="error",void C(e))},n.adf_body=arguments[0],Q({type:"xhr",requestMethod:n.adf_xhrOpenArgs[0],url:n.adf_xhrOpenArgs[1]},"network"))return void A(null,n);P(n)}catch(e){S(n)}finally{e.apply(n,arguments)}}}(t.XMLHttpRequest.prototype.send),function(e){t.open=function(){function n(){if(o&&!o.opener||a>100){try{o.opener=t}catch(e){}g(p)}else a+=1}var o;try{if(!D()||!$e)return void(o=e.apply(t,arguments));var d=arguments[0],r=i(),l=f(function(){I({name:"clickRecovery",timing:3e3})},3e3);z(t,"message",function(e){e.data.message&&"ping"===e.data.message&&e.data.tabId&&e.data.tabId===r&&(clearTimeout(l),e.source.postMessage({message:"pong",targetURL:d,tabId:r,video:!0},"*"))},!0),o=e.apply(t,[ze+"#"+r]);var p,a=0;try{o.opener=t}catch(e){}p=w(n,1)}catch(n){o=e.apply(t,arguments)}finally{return o}}}(t.open),function(n){e.onxvjcefFlags&&e.onxvjcefFlags.fetchRecoveryOff||(t.fetch=function(){var e=arguments;try{var o={type:"xhr",requestMethod:e&&e[1]&&e[1].method?e[1].method:"GET",url:e&&e[0]?e[0]:""};return D()&&o.url&&!G(o,"network")?(o.url=h(o.url),V(o. ...
# </script>
# <div class="werbung werbung-header">
# <!-- Start GPT Tag -->
# <script>
#                   window.googletag = window.googletag || {cmd: []};
#                   googletag.cmd.push(function() {
#                     googletag.defineSlot("/58778164/Desktop-Billboard-1", [[960, 90], [970, 250], [950, 90], [728, 90], [970, 90]], "div-gpt-ad-1621524903956-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-MediumRectangle-1", [[300, 250], [336, 280]], "div-gpt-ad-1621526463511-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Skyscraper-1", [[160, 600], [336, 280], [300, 250], [300, 600], [120, 600]], "div-gpt-ad-1621527521939-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-MediumRectangle-2", [[336, 280], [300, 250]], "div-gpt-ad-1621528018930-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Skyscraper-2",  [[300, 250], [336, 280], [160, 600], [300, 600], [120, 600]], "div-gpt-ad-1621528123398-0")
#                     .addService(googletag.pubads());
#                     googletag.defineSlot("/58778164/Desktop-Billboard-2",  [[950, 90], [970, 250], [728, 90], [970, 90], [960, 90], [300, 250]], "div-gpt-ad-1621528173524-0")
#                     .addService(googletag.pubads());
#                      googletag.pubads().enableLazyLoad({
#                         fetchMarginPercent: 500,
#                         renderMarginPercent: 200,
#                         mobileScaling: 2.0});
#                     googletag.pubads().setCentering(true);
#                     googletag.pubads().disableInitialLoad();
#                     googletag.pubads().enableSingleRequest();
#                     googletag.pubads().setTargeting("cg1", ["marktwertetop"]);
#                     googletag.pubads().setTargeting("URL", "www.transfermarkt.com");
#                     googletag.enableServices();
#                   });
#                 </script>
# <!-- End GPT Tag -->
# </div></link></link></head>
# <body class="" data-cmp-layer-id="910164" data-tm-tld="com" itemscope="" itemtype="http://schema.org/WebPage">
# <div id="main">
# <div class="werbung-skyscraper-container">
# <div class="werbung werbung-skyscraper"><div id="div-gpt-ad-1621527521939-0" style="min-width: 160px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621527521939-0"); });</script>
# </div> </div>
# <div class="werbung-skyscraperbtf-container">
# <div class="werbung werbung-skyscraperbtf"><div id="div-gpt-ad-1621528123398-0" style="min-width: 160px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528123398-0"); });</script>
# </div> </div>
# <header class="tm-header">
# <div class="tm-header__box">
# <a href="/">
# <img alt="Transfermarkt" class="icon-logo" height="62" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" title="Transfermarkt" width="156"/>
# </a>
# <tm-domainswitcher open-list="false" tld="com"></tm-domainswitcher>
# <div class="tm-header__social-box">
# <a class="header__social-link" href="https://www.facebook.com/Transfermarkt.global" onclick="tmEvent('SM-Icons_Header','click','Facebook');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/fb_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link header__social-link--twitter" href="https://twitter.com/TMuk_news" onclick="tmEvent('SM-Icons_Header','click','Twitter');
# " target="_blank">
# <img class="header__icon header__icon--twitter" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/twitter.svg" width="20"/>
# </a>
# <a class="header__social-link" href="http://instagram.com/transfermarkt_official" onclick="tmEvent('SM-Icons_Header','click','Instagram');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/instagram_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="/intern/rssguide" onclick="tmEvent('SM-Icons_Header','click','RSS');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/socialMedia/rss_icon_hover.svg" width="20"/>
# </a>
# <a class="header__social-link" href="https://www.tiktok.com/@transfermarkt" onclick="tmEvent('SM-Icons_Header','click','Tiktok');
# " target="_blank">
# <img class="header__icon" height="20" src="https://tmsi.akamaized.net/icons/tiktokRebrush.svg" width="20"/>
# </a>
# </div>
# <div class="tm-header__input-wrapper" id="schnellsuche-platz">
# <form action="/schnellsuche/ergebnis/schnellsuche" class="tm-header__form" id="schnellsuche" name="schnellsuche">
# <input autocorrect="off" class="tm-header__input--search-field" name="query" onclick="" placeholder="Enter search term" spellcheck="false" type="text" value=""/>
# <input alt="search" class="tm-header__input--search-send" type="submit" value=""/>
# </form>
# <a class="tm-header__search-detail" href="/detailsuche/spielerdetail/suche" id="detailsuche-head" title="To the player detail search">
# <img alt="search" class="tm-header__icon-detail-search" height="26" src="https://tmsi.akamaized.net/icons/search_icon_plus_blue_white.svg" width="26"/>
# </a>
# </div>
# </div>
# <nav class="main-navbar navihalter">
# <ul class="main-navbar__container megamenu_dark_bar megamenu_dark" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <a class="sticky-logo hide-for-small" href="/">
# <span class="tm_svg" title="Transfermarkt"></span>
# </a>
# <li class="main-navbar__list" data-nav-group="news">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('News','click','menu');
# ">
#             News        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="transfers">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Transfers &amp; Gerüchte','click','menu');
# ">
#             Transfers &amp; rumours        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list aktiv" data-nav-group="marktwerte">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Marktwerte','click','menu');
# ">
#             Market values        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="wettbewerbe">
# <span class="main-navbar__list-title tm-main-nav-el" onclick="tmEvent('Wettbewerbe','click','menu');
# ">
#             Competitions        </span>
# <div class="main-navbar__drop-down">
# <img class="navigation-loading-spinner" height="40" src="https://tmsi.akamaized.net/icons/tm_spinner_inverted.min.svg" width="40">
# </img></div>
# <li class="main-navbar__list" data-nav-group="foren">
# ...
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         End of loan                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
# </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Almamy Touré" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/216181-1700140427.jpg?lm=1" title="Almamy Touré"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/almamy-toure/profil/spieler/216181" title="Almamy Touré">Almamy Touré</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Back                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/almamy-toure/transfers/spieler/216181/transfer_id/4731842?from=neustetransfersbox" title="Almamy Touré">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/1-fc-kaiserslautern/transfers/verein/2" title="1.FC Kaiserslautern"><img alt="1.FC Kaiserslautern" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/2.png?lm=1580920736" title="1.FC Kaiserslautern"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/almamy-toure/transfers/spieler/216181/transfer_id/4731842?from=neustetransfersbox" title="Almamy Touré">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2024                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Jefté Betancor" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/198015-1661769903.jpg?lm=1" title="Jefté Betancor"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/jefte-betancor/profil/spieler/198015" title="Jefté Betancor">Jefté Betancor</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Centre-Forward                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/cfr-cluj/transfers/verein/7769" title="CFR Cluj"><img alt="CFR Cluj" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/7769.png?lm=1414777942" title="CFR Cluj"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/jefte-betancor/transfers/spieler/198015/transfer_id/4731376?from=neustetransfersbox" title="Jefté Betancor">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/jefte-betancor/transfers/spieler/198015/transfer_id/4731376?from=neustetransfersbox" title="Jefté Betancor">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             -                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="André Ayew" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/45403-1668429304.jpg?lm=1" title="André Ayew"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/andre-ayew/profil/spieler/45403" title="André Ayew">André Ayew</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Left Winger                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/vereinslos/transfers/verein/515" title="Without ClubWithout Club"><img alt="Without Club" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/515.png?lm=1456997255" title="Without Club"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/andre-ayew/transfers/spieler/45403/transfer_id/4727561?from=neustetransfersbox" title="André Ayew">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/ac-le-havre/transfers/verein/738" title="Le Havre AC"><img alt="Le Havre AC" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/738.png?lm=1408780648" title="Le Havre AC"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/andre-ayew/transfers/spieler/45403/transfer_id/4727561?from=neustetransfersbox" title="André Ayew">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2024                    </div>
# </div>
# </a>
# </td>
# </tr>
# <tr>
# <td>
# <div class="inline-table" style="max-width: 200px;">
# <div class="statistik-widget--spielerbild" style="float: left;">
# <img alt="Kristian Hlynsson" class="bilderrahmen-home-fixed" src="https://img.a.transfermarkt.technology/portrait/small/694186-1664796563.jpg?lm=1" title="Kristian Hlynsson"/> </div>
# <div class="statistik-widget-letztetransfers-spielername">
# <a href="/kristian-hlynsson/profil/spieler/694186" title="Kristian Hlynsson">K. Hlynsson</a> </div>
# <div class="statistik-widget-letztetransfers-position">
#                         Attacking Midfield                    </div>
# <div style="clear: both;"></div>
# </div>
# </td>
# <td class="zentriert no-border-rechts" style="min-width: 10px; padding: 2px 0 0;">
# <a href="/ajax-amsterdam-ii/transfers/verein/8817" title="Ajax Amsterdam U21"><img alt="Ajax Amsterdam U21" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/8817.png?lm=1657054414" title="Ajax Amsterdam U21"/></a> </td>
# <td class="zentriert no-border-rechts no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/kristian-hlynsson/transfers/spieler/694186/transfer_id/4722282?from=neustetransfersbox" title="Kristian Hlynsson">
# <span class="icons_sprite icon-einwechslung-formation" style="margin-top: -1px; white-space: nowrap;" title="Transfer"> </span>
# </a>
# </td>
# <td class="zentriert no-border-links" style="min-width: 10px; padding: 0;">
# <a href="/ajax-amsterdam/transfers/verein/610" title="Ajax Amsterdam"><img alt="Ajax Amsterdam" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/610.png?lm=1657054414" title="Ajax Amsterdam"/></a> </td>
# <td class="rechts" style="padding-right: 2px;">
# <a href="/kristian-hlynsson/transfers/spieler/694186/transfer_id/4722282?from=neustetransfersbox" title="Kristian Hlynsson">
# <div class="inline-table" style="width:100%;">
# <div class="statistik-widget-letztetransfers-abloese rechts hauptlink">
#                         -                    </div>
# <div class="statistik-widget-letztetransfers-datum rechts">
#                             Jun 30, 2026                    </div>
# </div>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="content-link" href="/statistik/letztetransfers">Complete list</a>
# </div>
# <div class="werbung werbung-rectangle2"><div id="div-gpt-ad-1621528018930-0" style="min-width: 300px; min-height: 250px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528018930-0"); });</script>
# </div> </div>
# </div>
# <div class="werbung werbung-fullsize_contentad"><div id="div-gpt-ad-1621528173524-0" style="min-width: 728px; min-height: 90px;"></div>
# <script>googletag.cmd.push(function() { googletag.display("div-gpt-ad-1621528173524-0"); });</script>
# </div> </main>
# <footer>
# <div class="tm-footer">
# <a class="tm-footer__logo" href="/">
# <img alt="Transfermarkt" height="33" src="https://tmsi.akamaized.net/head/transfermarkt_logo.svg" width="80"/>
# </a>
# <ul class="tm-footer__links">
# <li class="tm-footer__links-item">
# <a href="/intern/impressum">
#           Legal notice      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/web/datenschutz">
#           Data protection      </a>
# </li>
# <li class="tm-footer__links-item">
# <a class="cmp-link" href="javascript:void(0)">
#           Privacy      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/anb">
#           General terms of use      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/tmteam">
#           The TM team      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/faq">
#           FAQ      </a>
# </li>
# <li class="tm-footer__links-item">
# <a href="/intern/fehlermelden">
#           Found a mistake?      </a>
# </li>
# </ul>
# </div>
# </footer>
# <div id="menue_overlay"></div>
# </div>
# <script type="text/javascript">
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r",
# "co":""
# }
#     </script>
# <script type="module">
#         var defaultOptions = {
#             tracking: !0,
#             refreshAds: !0
#         };
#         export var refreshAd = function() {
#             var e, n;
#             [ASCDP.hasOwnProperty("adS"), null === (e = ASCDP.adS) || void 0 === e ? void 0 : e.hasOwnProperty("reloadAds"), "function" == typeof(null === (n = ASCDP.adS) || void 0 === n ? void 0 : n.reloadAds)].every(function(e) {
#                 return e
#             }) && ASCDP.adS.reloadAds()
#         };
#         export var TmTrackingAndAds = function(e, n) {
#             void 0 === n && (n = defaultOptions);
#             var r = ["tabelle", "reiter", "forum"].includes(e) ? e : "";
#             n.tracking && (gtag("event", "page_view", {
#                 page_path: "/jsContent" + window.location.pathname
#             }), sendIvwData(r)), n.refreshAds && "undefined" != typeof ASCDP && refreshAd()
#         };
#         window.tmTrackingAndAds = function(e, n) {
#             return TmTrackingAndAds(e, n)
#         };
#     </script>
# <script type="text/javascript">
#             const iommInterval = setInterval(() => {
#                 if (typeof IOMm === 'function') {
#                     IOMm('configure', {
#                         st: iam_data.st,
#                         dn: 'data-84a0f3455d.transfermarkt.com',
#                         mh: 5
#                     });
#                     IOMm('pageview', {
#                         cp: iam_data.cp,
#                         co: iam_data.co
#                     });
#                     clearInterval(iommInterval);
#                 }
#             }, 250);
#         </script>
# <script type="text/javascript">
# 	if(typeof(adet) == "boolean" && adet == false){
# 		img_src="/static/singlepictures/jk99hhfsdh209nbnkjldgh90sghfsdlk";
# 	} else {
# 		img_src="/static/singlepictures/jku90whjlkjbwbta1g4b8h89fh8sgh8d";
# 	}
# 	var elem = document.createElement("img");
# 	document.body.appendChild(elem);
# 	elem.src = img_src;
# </script>
# <script>
#             $(function() {
#                 var cnt = $('div.large-4.columns').length;
#                 if (cnt == 1) {
#                     var sidebarDiv = document.querySelector('div.large-4.columns');
#                     if (sidebarDiv !== null) {
#                         $('#werbung_recommender_sidebar_wrapper').appendTo(sidebarDiv);
#                         $('#werbung_recommender_sidebar_wrapper').show();
#                     }
#                 }
#             });
#         </script>
# <div id="werbung_recommender_sidebar_wrapper" style="display: none;">
# <div class="box" id="recommender_sidebar">
# <div class="OUTBRAIN" data-widget-id="SL_DT_SB"></div>
# <tm-consent embed="PHNjcmlwdCB0eXBlPSJ0ZXh0L2phdmFzY3JpcHQiIGFzeW5jPSJhc3luYyIgc3JjPSIvL3dpZGdldHMub3V0YnJhaW4uY29tL291dGJyYWluLmpzIj48L3NjcmlwdD4=" no-checkbox="" type="outbrain"></tm-consent>
# </div>
# </div>
# <script defer="" src="https://tmsi.akamaized.net/js/custom-element-globals/tm-global-elements.esm.js" type="module"></script><script defer="" nomodule="" src="https://tmsi.akamaized.net/js/custom-element-globals/tm-global-elements.js"></script> <tm-consent embed="..." no-checkbox="" type="nielsen">
# </tm-consent>
# <script defer="" src="https://tmsi.akamaized.net/js/svelte-components-2d3db030/consent/bundle.js"></script><script src="https://tmssl.akamaized.net/assets/aa69c6e9c51f1e811847082c63633956/gridview/jquery.yiigridview.js?lm=1700238204" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/tm-menu.min.js?lm=1700238203" type="text/javascript"></script>
# <script src="https://tmssl.akamaized.net/js/custom/vendors.min.js?lm=1700238203" type="text/javascript"></script>
# <script type="text/javascript">
# /*<![CDATA[*/
# function skyscraperSwitch() {
#                const firstAd = document.getElementsByClassName("werbung-skyscraper");
#                const secondAd = document.getElementsByClassName("werbung-skyscraperbtf")
#                 if (this.scrollY > 699) {
#                     firstAd[0].style.visibility = "hidden";
#                     secondAd[0].style.position = "fixed";
#                     secondAd[0].style.top = "40px";
#                 } else {
#                     firstAd[0].style.visibility = "visible";
#                     secondAd[0].style.position = "relative";
#                     secondAd[0].style.top = "unset";
#                 }
#             }
#             window.addEventListener("scroll", skyscraperSwitch, false);
# 	var loginUrl='/profil/login';
# 	var onlyDE = '';
# 	var onlyMobile = '';
# 	var onlyTablet = '';
# 	var getUserID = '';
#
# function sendIvwData(typ) {
#     if(typ == 'tabelle') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_t",
# "co":""
# }
#
#     }else if(typ == 'reiter') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_r",
# "co":""
# }
#
#     }else if(typ == 'forum') {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_forum",
# "co":""
# }
#
#     }else {
#         var iam_data = {
# "st":"transfer",
# "cp":"ausland_co.uk_r_s",
# "co":""
# }
#
#     }
#     if(typeof IOMm === 'function') {
#         IOMm('pageview', { cp: iam_data.cp, co: iam_data.co });
#     }
# }
# window.articlemetadata = {
#     type: "static",
#     assetid: 'statistik-global',
#     section:  'statistik',
#     segA: iam_data.cp,
#     segB: "CPI",
#     segC: "",
#     subbrand: "c18"
#     };
#
# jQuery(function($) {
# jQuery('#yw1').yiiGridView({'ajaxUpdate':['yw1'],'ajaxVar':'ajax','pagerClass':'pager','loadingClass':'grid\x2Dview\x2Dloading','filterClass':'filters','tableClass':'items','selectableRows':1,'enableHistory':false,'updateSelector':'\x7Bpage\x7D,\x20\x7Bsort\x7D','filterSelector':'\x7Bfilter\x7D','pageVar':'page','afterAjaxUpdate':function() {window.LazyLoadInstance.update(); tmTrackingAndAds(); document.dispatchEvent(new CustomEvent("tmInitTooltip"));}});
# });
# /*]]>*/
# </script>
# </body>
# </html>

# %%
player_info = soup.find_all('tr', class_=['odd', 'even'])
print(player_info[0])
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Erling Haaland" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/418560-1694590614.jpg?lm=1" title="Erling Haaland"/></a></td><td class="hauptlink"><a href="/erling-haaland/profil/spieler/418560" title="Erling Haaland">Erling Haaland</a></td></tr><tr><td>Centre-Forward</td></tr></table></td><td class="zentriert">23</td><td class="zentriert"><img alt="Norway" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/125.png?lm=1520611569" title="Norway"/></td><td class="zentriert"><a href="/manchester-city/startseite/verein/281" title="Manchester City"><img alt="Manchester City" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/281.png?lm=1467356331" title="Manchester City"/></a></td><td class="rechts hauptlink"><a href="/erling-haaland/marktwertverlauf/spieler/418560">€180.00m</a> </td></tr>

# %%
print(len(player_info))
# Out:
# 25

# %%
number, name, position, age, nation, team, value = [], [], [], [], [], [], []

for info in player_info:
    player = info.find_all("td")
    number.append(player[0].text)
    name.append(player[3].text)
    position.append(player[4].text)
    age.append(player[5].text)
    nation.append(player[6].img['alt'])
    team.append(player[7].img['alt'])
    value.append(player[8].text.strip())

# %%
for info in player_info:
    player = info.find_all("td")
    print(player[8])
# Out:
# <td class="rechts hauptlink"><a href="/erling-haaland/marktwertverlauf/spieler/418560">€180.00m</a> </td>
# <td class="rechts hauptlink"><a href="/kylian-mbappe/marktwertverlauf/spieler/342229">€180.00m</a> </td>
# <td class="rechts hauptlink"><a href="/jude-bellingham/marktwertverlauf/spieler/581678">€150.00m</a> </td>
# <td class="rechts hauptlink"><a href="/vinicius-junior/marktwertverlauf/spieler/371998">€150.00m</a> </td>
# <td class="rechts hauptlink"><a href="/bukayo-saka/marktwertverlauf/spieler/433177">€120.00m</a> </td>
# <td class="rechts hauptlink"><a href="/victor-osimhen/marktwertverlauf/spieler/401923">€120.00m</a> </td>
# <td class="rechts hauptlink"><a href="/jamal-musiala/marktwertverlauf/spieler/580195">€110.00m</a> </td>
# <td class="rechts hauptlink"><a href="/phil-foden/marktwertverlauf/spieler/406635">€110.00m</a> </td>
# <td class="rechts hauptlink"><a href="/harry-kane/marktwertverlauf/spieler/132098">€110.00m</a> </td>
# <td class="rechts hauptlink"><a href="/pedri/marktwertverlauf/spieler/683840">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/rodrygo/marktwertverlauf/spieler/412363">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/lautaro-martinez/marktwertverlauf/spieler/406625">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/federico-valverde/marktwertverlauf/spieler/369081">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/declan-rice/marktwertverlauf/spieler/357662">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/rodri/marktwertverlauf/spieler/357565">€100.00m</a> </td>
# <td class="rechts hauptlink"><a href="/moises-caicedo/marktwertverlauf/spieler/687626">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/gavi/marktwertverlauf/spieler/646740">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/eduardo-camavinga/marktwertverlauf/spieler/640428">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/aurelien-tchouameni/marktwertverlauf/spieler/413112">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/rafael-leao/marktwertverlauf/spieler/357164">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/frenkie-de-jong/marktwertverlauf/spieler/326330">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/martin-odegaard/marktwertverlauf/spieler/316264">€90.00m</a> </td>
# <td class="rechts hauptlink"><a href="/florian-wirtz/marktwertverlauf/spieler/598577">€85.00m</a> </td>
# <td class="rechts hauptlink"><a href="/bruno-guimaraes/marktwertverlauf/spieler/520624">€85.00m</a> </td>
# <td class="rechts hauptlink"><a href="/khvicha-kvaratskhelia/marktwertverlauf/spieler/502670">€85.00m</a> </td>
